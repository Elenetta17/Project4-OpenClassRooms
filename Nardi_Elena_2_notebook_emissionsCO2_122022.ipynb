# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Anticipez-les-besoins-en-consommation-de-bâtiments" data-toc-modified-id="Anticipez-les-besoins-en-consommation-de-bâtiments-1"><strong>Anticipez les besoins en consommation de bâtiments</strong></a></span></li><li><span><a href="#0.Imports-and-functions" data-toc-modified-id="0.Imports-and-functions-2">0.Imports and functions</a></span></li><li><span><a href="#1.-Encodage-des-données" data-toc-modified-id="1.-Encodage-des-données-3">1. Encodage des données</a></span></li><li><span><a href="#2.-Baseline-model" data-toc-modified-id="2.-Baseline-model-4">2. Baseline model</a></span></li><li><span><a href="#3.-Régressions-linéaires" data-toc-modified-id="3.-Régressions-linéaires-5">3. Régressions linéaires</a></span><ul class="toc-item"><li><span><a href="#3.1-Premières-modélisations" data-toc-modified-id="3.1-Premières-modélisations-5.1">3.1 Premières modélisations</a></span></li><li><span><a href="#3.2-Logarithme-de-la-variable-cible" data-toc-modified-id="3.2-Logarithme-de-la-variable-cible-5.2">3.2 Logarithme de la variable cible</a></span></li><li><span><a href="#3.3-Transformation-des-variables" data-toc-modified-id="3.3-Transformation-des-variables-5.3">3.3 Transformation des variables</a></span></li><li><span><a href="#3.4-Inverses-des-variables" data-toc-modified-id="3.4-Inverses-des-variables-5.4">3.4 Inverses des variables</a></span></li><li><span><a href="#3.5--Best-Linear-Regression" data-toc-modified-id="3.5--Best-Linear-Regression-5.5">3.5  Best Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Importance-des-variables" data-toc-modified-id="Importance-des-variables-5.5.1">Importance des variables</a></span></li></ul></li></ul></li><li><span><a href="#4.-Régression-Lasso" data-toc-modified-id="4.-Régression-Lasso-6">4. Régression Lasso</a></span><ul class="toc-item"><li><span><a href="#4.1-Premières-modélisations" data-toc-modified-id="4.1-Premières-modélisations-6.1">4.1 Premières modélisations</a></span></li><li><span><a href="#4.2-Logarithme-de-la-variable-cible" data-toc-modified-id="4.2-Logarithme-de-la-variable-cible-6.2">4.2 Logarithme de la variable cible</a></span></li><li><span><a href="#4.3-Transformation-des-variables" data-toc-modified-id="4.3-Transformation-des-variables-6.3">4.3 Transformation des variables</a></span></li><li><span><a href="#4.4-Inverses-des-variables" data-toc-modified-id="4.4-Inverses-des-variables-6.4">4.4 Inverses des variables</a></span></li><li><span><a href="#4.5-Best-Lasso-Regression" data-toc-modified-id="4.5-Best-Lasso-Regression-6.5">4.5 Best Lasso Regression</a></span><ul class="toc-item"><li><span><a href="#Importance-des-variables" data-toc-modified-id="Importance-des-variables-6.5.1">Importance des variables</a></span></li></ul></li></ul></li><li><span><a href="#5.Régression-Ridge" data-toc-modified-id="5.Régression-Ridge-7">5.Régression Ridge</a></span><ul class="toc-item"><li><span><a href="#5.1-Premières-modélisations" data-toc-modified-id="5.1-Premières-modélisations-7.1">5.1 Premières modélisations</a></span></li><li><span><a href="#5.2-Logarithme-de-la-variable-cible" data-toc-modified-id="5.2-Logarithme-de-la-variable-cible-7.2">5.2 Logarithme de la variable cible</a></span></li><li><span><a href="#5.3-Transformation-des-variables" data-toc-modified-id="5.3-Transformation-des-variables-7.3">5.3 Transformation des variables</a></span></li><li><span><a href="#5.4-Inverses-des-variables" data-toc-modified-id="5.4-Inverses-des-variables-7.4">5.4 Inverses des variables</a></span></li><li><span><a href="#5.5-Best-Ridge-Regression" data-toc-modified-id="5.5-Best-Ridge-Regression-7.5">5.5 Best Ridge Regression</a></span><ul class="toc-item"><li><span><a href="#Importance-des-variables" data-toc-modified-id="Importance-des-variables-7.5.1">Importance des variables</a></span></li></ul></li></ul></li><li><span><a href="#6.-Support-Vector-Regression-(SVR)" data-toc-modified-id="6.-Support-Vector-Regression-(SVR)-8">6. Support Vector Regression (SVR)</a></span><ul class="toc-item"><li><span><a href="#6.1-Premières-modélisations" data-toc-modified-id="6.1-Premières-modélisations-8.1">6.1 Premières modélisations</a></span></li><li><span><a href="#6.2-Logarithme-de-la-variable-cible" data-toc-modified-id="6.2-Logarithme-de-la-variable-cible-8.2">6.2 Logarithme de la variable cible</a></span></li><li><span><a href="#6.3-Inverses-des-variables" data-toc-modified-id="6.3-Inverses-des-variables-8.3">6.3 Inverses des variables</a></span></li><li><span><a href="#6.4-Best-SVR" data-toc-modified-id="6.4-Best-SVR-8.4">6.4 Best SVR</a></span><ul class="toc-item"><li><span><a href="#Importance-des-variables" data-toc-modified-id="Importance-des-variables-8.4.1">Importance des variables</a></span></li></ul></li></ul></li><li><span><a href="#7.-RandomForest" data-toc-modified-id="7.-RandomForest-9">7. RandomForest</a></span><ul class="toc-item"><li><span><a href="#7.1-Premières-modélisations" data-toc-modified-id="7.1-Premières-modélisations-9.1">7.1 Premières modélisations</a></span></li><li><span><a href="#7.2-Logarithme-de-la-variable-cible" data-toc-modified-id="7.2-Logarithme-de-la-variable-cible-9.2">7.2 Logarithme de la variable cible</a></span></li><li><span><a href="#7.3-Inverses-des-variables" data-toc-modified-id="7.3-Inverses-des-variables-9.3">7.3 Inverses des variables</a></span></li><li><span><a href="#7.4-Best-Random-Forest-Regression" data-toc-modified-id="7.4-Best-Random-Forest-Regression-9.4">7.4 Best Random Forest Regression</a></span><ul class="toc-item"><li><span><a href="#Importance-des-variables" data-toc-modified-id="Importance-des-variables-9.4.1">Importance des variables</a></span></li></ul></li></ul></li><li><span><a href="#8.-XGBoost" data-toc-modified-id="8.-XGBoost-10">8. XGBoost</a></span><ul class="toc-item"><li><span><a href="#8.1-Premières-modélisations" data-toc-modified-id="8.1-Premières-modélisations-10.1">8.1 Premières modélisations</a></span></li><li><span><a href="#8.2-Logarithme-de-la-variable-cible" data-toc-modified-id="8.2-Logarithme-de-la-variable-cible-10.2">8.2 Logarithme de la variable cible</a></span></li><li><span><a href="#8.3-Inverses-des-variables" data-toc-modified-id="8.3-Inverses-des-variables-10.3">8.3 Inverses des variables</a></span></li><li><span><a href="#8.4-Best-XGB-Regression" data-toc-modified-id="8.4-Best-XGB-Regression-10.4">8.4 Best XGB Regression</a></span><ul class="toc-item"><li><span><a href="#Importance-des-variables" data-toc-modified-id="Importance-des-variables-10.4.1">Importance des variables</a></span></li></ul></li></ul></li><li><span><a href="#9.-Comparaison-des-modèles-et-sélection-du-meilleur-modèle" data-toc-modified-id="9.-Comparaison-des-modèles-et-sélection-du-meilleur-modèle-11">9. Comparaison des modèles et sélection du meilleur modèle</a></span></li><li><span><a href="#10.-Analyse-de-l'intérêt-de-l'Energy-Star-Score-et-explication-du-modèle" data-toc-modified-id="10.-Analyse-de-l'intérêt-de-l'Energy-Star-Score-et-explication-du-modèle-12">10. Analyse de l'intérêt de l'Energy Star Score et explication du modèle</a></span><ul class="toc-item"><li><span><a href="#10.1-Analyse-de-l'Energy-Star-Score" data-toc-modified-id="10.1-Analyse-de-l'Energy-Star-Score-12.1">10.1 Analyse de l'Energy Star Score</a></span><ul class="toc-item"><li><span><a href="#10.1.1-Entrainement-sur-le-jeu-de-données-complet-sans-ENERGY-STAR-Score" data-toc-modified-id="10.1.1-Entrainement-sur-le-jeu-de-données-complet-sans-ENERGY-STAR-Score-12.1.1">10.1.1 Entrainement sur le jeu de données complet sans ENERGY STAR Score</a></span></li><li><span><a href="#10.1.2-Entrainement-sur-le-jeu-de-données-partiel-avec-ENERGY-STAR-Score" data-toc-modified-id="10.1.2-Entrainement-sur-le-jeu-de-données-partiel-avec-ENERGY-STAR-Score-12.1.2">10.1.2 Entrainement sur le jeu de données partiel avec ENERGY STAR Score</a></span></li><li><span><a href="#10.1.3-Entrainement-sur-le-jeu-de-données-partiel-sans-ENERGY-STAR-Score" data-toc-modified-id="10.1.3-Entrainement-sur-le-jeu-de-données-partiel-sans-ENERGY-STAR-Score-12.1.3">10.1.3 Entrainement sur le jeu de données partiel sans ENERGY STAR Score</a></span></li></ul></li><li><span><a href="#10.2-Explication-du-modèle" data-toc-modified-id="10.2-Explication-du-modèle-12.2">10.2 Explication du modèle</a></span></li></ul></li><li><span><a href="#11.-Conclusions" data-toc-modified-id="11.-Conclusions-13">11. Conclusions</a></span></li></ul></div>

# %% [markdown]
# # **Anticipez les besoins en consommation de bâtiments**

# %% [markdown]
# Pour atteindre son objectif de ville neutre en émissions de carbone en 2050, mon équipe s’intéresse de près à la consommation et aux émissions des bâtiments non destinés à l’habitation.
#
# Des relevés minutieux ont été effectués par les agents de la ville de Seattle en 2016. Voici les données et leur source:
#
#  - https://s3.eu-west-1.amazonaws.com/course.oc-static.com/projects/Data_Scientist_P4/2016_Building_Energy_Benchmarking.csv
#
# - https://data.seattle.gov/dataset/2016-Building-Energy-Benchmarking/2bpz-gwpy
#
#
# Cependant, ces relevés sont coûteux à obtenir, et à partir de ceux déjà réalisés, je veux tenter de prédire les émissions de CO<sub>2</sub> et la consommation totale d’énergie de bâtiments non destinés à l’habitation pour lesquels elles n’ont pas encore été mesurées.
#
# Je cherche également à évaluer l’intérêt de l’"ENERGY STAR Score"* pour la prédiction, qui est fastidieux à calculer avec l’approche utilisée actuellement par mon équipe. Je vais l'intégrer dans la modélisation et je vais juger de son intérêt.
#
# Voici un récapitulatif de la mission :
#
#  - Réaliser une courte analyse exploratoire
#  - Tester différents modèles de prédiction afin de répondre au mieux à la problématique
#  - Analyse de l'interet de l'ENERGY STAR Score
#
# Ce notebook est consacré à la prédiction des émissions de CO<sub>2</sub> (pour rappel, la variable cible est la `GHGEmissionsIntensity`). Le jeu des données utilisé pour les tests des différents modèles est celui avec la variable `ENERGYSTARScore` imputée. Une fois le meilleur modèle choisi, je vais entrainer le modèle et faire des prédictions pour un jeu des données composé des immeubles pour lesquels cette variable était manquante et un jeu des données pour lequel cette variable n'était pas manquante. Ceci me permettra de juger l'intérêt de la variable.
#
# *<span style=font-size:12px>The ENERGY STAR score provides a comprehensive snapshot of your building’s energy performance, taking into account the building’s physical assets, operations, and occupant behavior. It is expressed on an easy-to-understand 1 to 100 scale, where the higher the score, the better the energy performance of the building. It’ll help you identify which buildings in your portfolio to target for improvement or recognition.</span>

# %% [markdown]
# # 0.Imports and functions

# %%
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import r2_score,  mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import RobustScaler
from sklearn.svm import SVR
from xgboost import XGBRegressor

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap
import time

# %%
def score(y_true, pred):
    """Cette fonction prend en entrée les données du jeu de test et les données prédites, et retourne un Dataframe avec 3 scores:
    R2, Mean Absolute Error (MAE) et Root Mean Squared Error (RMSE)"""
    #scores
    a = r2_score(y_true, pred)
    b = mean_absolute_error(y_true, pred)
    c = mean_squared_error(y_true, pred, squared=False)
    return pd.DataFrame([a,b,c], index = ['R2', 'MAE', 'RMSE'], columns = ['Scores'])


def inverse_variables(X_train, X_test):
    """Cette fonction prend en entrée un jeu de données d'entrainement et un jeu de données de test et y rajoute les inverses des variables"""
    inversed_cols = ['Inverse_' + col for col in X_train.columns] #nom des inverses des variables
    inversed_train = 1/(X_train+1) #calculs inverses sur le train set (le + 1 est pour ne pas avoir des valeurs infinis)
    inversed_train.columns = inversed_cols 
    inversed_test = 1/(X_test+1) #calculs inverses sur le test set (le + 1 est pour ne pas avoir des valeurs infinis)
    inversed_test.columns = inversed_cols
    X_train = pd.concat([X_train, inversed_train], axis = 1) #concatenation inverses train set
    X_test = pd.concat([X_test, inversed_test], axis = 1) #concatenation inverses test set
    return X_train, X_test

def cv_scores(estimator, X, y):
    """Cette fonction prend en entrée un estimator, un jeu de données et une variable cible, effectue une cross validation, imprime le runtime moyen et retourne un DataFrame
    avec R2, MAE et RMSE moyens sur les training folds et sur le validation fold"""
    results = cross_validate(estimator, X, y, cv=5, verbose = 3, scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'r2'], return_train_score=True)
    train_rmse = -results['train_neg_root_mean_squared_error'].mean()
    test_rmse = -results['test_neg_root_mean_squared_error'].mean()
    train_mae = -results['train_neg_mean_absolute_error'].mean()
    test_mae = -results['test_neg_mean_absolute_error'].mean()
    train_r2 = results['train_r2'].mean()
    test_r2 = results['test_r2'].mean()
    print('\nMean runtime: {:.3f}'.format(results['fit_time'].mean()))
    return pd.DataFrame([[train_r2, test_r2], [train_mae, test_mae], [train_rmse, test_rmse]], index = ['R2', 'MAE', 'RMSE'], columns=['Mean Train Folds', 'Mean Validation Fold'])

# %%
#paramètres matplotlib
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['axes.labelsize'] = 11

# %% [markdown]
# # 1. Encodage des données

# %% [markdown]
# Les variables catégorielles sont 3 : `PrimaryPropertyType`, `ZipCode` et `Neighborhood`.
# Il faut les encoder pour pouvoir effectuer de modélisations. Le choix s'est porté sur le Target Encoding, car avec le OneHotEncoder j'aurais créé 84 variables et le risque d'overfitting aurait été agrandi.
#
# (NB: quand j'ai commencé à effectuer des modélisations, j'ai fait quelque test préliminaire avec le OneHotEncoding que je ne vais pas présenter ici; les résultats étaient très mauvais)

# %%
#lecture données
train = pd.read_csv('Data/GHE_train.csv')
test = pd.read_csv('Data/GHE_test.csv')

# %%
#sélection variables catégorielles
categorical_columns = ['PrimaryPropertyType', 'ZipCode', 'Neighborhood']
categorical_columns
# Out:
# ['PrimaryPropertyType', 'ZipCode', 'Neighborhood']

# %%
#séparation en variables indépendantes et variable cible
y_train = train['GHGEmissionsIntensity']
X_train = train.drop(['GHGEmissionsIntensity'], axis = 1)
y_test = test['GHGEmissionsIntensity']
X_test = test.drop(['GHGEmissionsIntensity'], axis = 1)

# %%
#encodage des données
te = TargetEncoder(cols = categorical_columns)
X_train = te.fit_transform(X_train, y_train)
X_test = te.transform(X_test)
# Out:
# Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
# Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327

# %% [markdown]
# Pour comprendre la distribution des variables ainsi encodées, je vais plotter les histogrammes.

# %%
#distributions des variables encodées
fig, ax = plt.subplots(3, 2, figsize =(15, 13))
plt.subplot(3,2,1)
plt.hist(X_train['PrimaryPropertyType'], bins = 20)
plt.title('PrimaryPropertyType - train set')
plt.xlabel('PrimaryPropertyType encodé')
plt.ylabel("Nombre d'immeubles")
plt.subplot(3,2,2)
plt.hist(X_test['PrimaryPropertyType'], bins = 20)
plt.title('PrimaryPropertyType - test set')
plt.xlabel('PrimaryPropertyType encodé')
plt.ylabel("Nombre d'immeubles")

plt.subplot(3,2,3)
plt.hist(X_train['ZipCode'], bins = 20)
plt.title('ZipCode - train set')
plt.xlabel('ZipCode encodé')
plt.ylabel("Nombre d'immeubles")
plt.subplot(3,2,4)
plt.hist(X_test['ZipCode'], bins = 20)
plt.title('ZipCode - test set')
plt.xlabel('ZipCode encodé')
plt.ylabel("Nombre d'immeubles")

plt.subplot(3,2,5)
plt.hist(X_train['Neighborhood'], bins = 20)
plt.title('Neighborhood - train set')
plt.xlabel('Neighborhood encodé')
plt.ylabel("Nombre d'immeubles")
plt.subplot(3,2,6)
plt.hist(X_test['Neighborhood'], bins = 20)
plt.title('Neighborhood - test set')
plt.xlabel('Neighborhood encodé')
plt.ylabel("Nombre d'immeubles")

plt.tight_layout()

# %% [markdown]
# Les distributions des variables encodées sont similaires pour le train et test set. La distribution de la variable `ZipCpde` ressemble à une gaussienne, mais ce n'est pas exactement le cas pour les variables `Neighborhood` et `PrimaryPropertyType`. Dans la suite, je vais étudier l'effet des différents transformations de ces variables sur leurs distribution et sur les résultats des modélisations.

# %% [markdown]
# # 2. Baseline model

# %% [markdown]
# Pour avoir un modèle de référence, je vais entrainer un Dummy Model qui prédit toujours la moyenne de la variable cible.

# %%
#Dummy Regression
dummy_regression = DummyRegressor()

# %%
#cross validation scores
cv_scores(dummy_regression, X_train, y_train)
# Out:
# [CV] END  neg_mean_absolute_error: (train=-1.371, test=-1.532) neg_root_mean_squared_error: (train=-2.410, test=-2.490) r2: (train=0.000, test=-0.003) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-1.434, test=-1.337) neg_root_mean_squared_error: (train=-2.520, test=-2.008) r2: (train=0.000, test=-0.000) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-1.371, test=-1.501) neg_root_mean_squared_error: (train=-2.207, test=-3.154) r2: (train=0.000, test=-0.004) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-1.427, test=-1.398) neg_root_mean_squared_error: (train=-2.435, test=-2.390) r2: (train=0.000, test=-0.002) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-1.465, test=-1.304) neg_root_mean_squared_error: (train=-2.543, test=-1.888) r2: (train=0.000, test=-0.015) total time=   0.0s
#
# Mean runtime: 0.002
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.000000             -0.004635
# MAE           1.413525              1.414362
# RMSE          2.422908              2.386248

# %%
#score test set
y_dummy = dummy_regression.fit(X_train, y_train).predict(X_test)
score(y_test, y_dummy)
# Out:
#         Scores
# R2   -0.007835
# MAE   1.316991
# RMSE  1.964127

# %% [markdown]
# # 3. Régressions linéaires

# %% [markdown]
# Dans un premier temps, je vais entrainer des régressions linéaires sur le jeu de donné tel qu'il est, avec scaling des données et en rajoutant des features polynomiales.
#
# Ensuite je vais faire la même chose en transformant la variable cible, en testant plusieurs transformations sur les variables et en rajoutant les inverses des variables (par exemple 1/NumberofFloors).
#
# Pour le scaling, je vais utiliser le RobustScaler, qui permet de réduire l'effet des valeurs aberrantes.
#
# Je vais utiliser le jeu de données de train, X_train, pour l'entrainement et présenter les scores obtenus sur le jeu de test, X_test.

# %% [markdown]
# ## 3.1 Premières modélisations

# %%
#régression linéaire de base
linear = LinearRegression()
linear.fit(X_train, y_train)
y_linear= linear.predict(X_test)
score(y_test, y_linear)
# Out:
#         Scores
# R2    0.444181
# MAE   0.873812
# RMSE  1.458617

# %%
#régression linéaire avec scaling
linear_scaled = Pipeline(steps=[('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_scaled.fit(X_train, y_train)
y_linear_scaled = linear_scaled.predict(X_test)
score(y_test, y_linear_scaled)
# Out:
#         Scores
# R2    0.444181
# MAE   0.873812
# RMSE  1.458617

# %%
#régression linéaire avec features polynomiales et scaling
linear_scaled_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_scaled_poly.fit(X_train, y_train)
y_linear_scaled_poly = linear_scaled_poly.predict(X_test)
score(y_test, y_linear_scaled_poly)
# Out:
#         Scores
# R2    0.362493
# MAE   0.865115
# RMSE  1.562130

# %% [markdown]
# Le scaling des données n'as pas d'effet sur les scores, ce qui n'est pas étonnant vu qu'il s'agit d'une régression linéaire sans régularisation.
# L'ajout des features polynomiales semble empirer les scores.

# %% [markdown]
# ## 3.2 Logarithme de la variable cible

# %% [markdown]
# Pour essayer d'améliorer les scores, je vais entrainer des modèles en utilisant le logarithme de la variable cible, mais d'abord je vais comparer la distribution de la variable cible et de son logarithme.

# %%
#distributions de la variable cible et de son logarithme
fig, ax = plt.subplots(1, 2, figsize =(15, 5))
plt.subplot(1,2,1)
plt.hist(y_train, bins=30)
plt.title('GHGEmissionsIntensity')
plt.xlabel('GHGEmissionsIntensity (kg CO2/sf)')
plt.ylabel("Nombre d'immeubles")
plt.subplot(1,2,2)
plt.hist(np.log1p(y_train), bins = 30)
plt.title('log(GHGEmissionsIntensity)')
plt.xlabel('GHGEmissionsIntensity (log kg CO2/sf)')
plt.ylabel("Nombre d'immeubles")
# Out:
# Text(0, 0.5, "Nombre d'immeubles")

# %% [markdown]
# Le logarithme permet de réduire l'asymétrie de la variable cible et rendre la distribution légèrement plus similaire à une gaussienne.

# %%
#boxplot de la variable cible et de son logarithme
fig, ax = plt.subplots(1, 2, figsize =(15, 5))
plt.subplot(1,2,1)
sns.boxplot(y_train)
plt.title('Boxplot GHGEmissionsIntensity')
plt.subplot(1,2,2)
sns.boxplot(np.log1p(y_train))
plt.title('Boxplot log(GHGEmissionsIntensity)')
# Out:
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Boxplot log(GHGEmissionsIntensity)')

# %% [markdown]
# Le logarithme permet de réduire l'effet des valeurs aberrantes.

# %%
#initialisation de la variable cible tranformée
y_train_log = np.log1p(y_train)
y_test_log = np.log1p(y_test)

# %%
#régression simple
linear_log = LinearRegression()
linear_log.fit(X_train, y_train_log)
y_linear_log = linear_log.predict(X_test)
score(y_test_log, y_linear_log)
# Out:
#         Scores
# R2    0.667949
# MAE   0.227037
# RMSE  0.317900

# %%
#régression avec scaling
linear_log_scaled = Pipeline(steps=[('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_log_scaled.fit(X_train, y_train_log)
y_linear_log_scaled = linear_log_scaled.predict(X_test)
score(y_test_log, y_linear_log_scaled)
# Out:
#         Scores
# R2    0.667949
# MAE   0.227037
# RMSE  0.317900

# %%
#régression avec features polynomiales et scaling
linear_log_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_log_poly.fit(X_train, y_train_log)
y_linear_log_poly  = linear_log_poly.predict(X_test)
score(y_test_log, y_linear_log_poly)
# Out:
#         Scores
# R2    0.632915
# MAE   0.222088
# RMSE  0.334251

# %% [markdown]
# Le passage au logarithme permet une amélioration des scores : le score R2 augmente et MAE et RMSE baissent.
# Dans la suite, je vais continuer à entrainer des régressions linéaires avec le logarithme de la variable cible comme target.

# %% [markdown]
# ## 3.3 Transformation des variables

# %% [markdown]
# J'ai effectué plusieurs transformations des variables (log, racine carrée, racine cubique, quantile transformation - avec output = normal -  et power transformation). Pour rendre ce notebook plus lisible, je ne vais pas présenter le détail de toutes les transformations effectuées et montrer toutes les distributions. Je vais me limiter à illustrer la méthodologie et montrer les effets des transformation choisies sur les distributions .

# %% [markdown]
# Pour chaque variable et chaque transformation je crée une copie du train et test set et entraine une régression linéaire pour comparer le score avec celui de la régression linéaire sans variable transformée.
#
# Je choisi la transformation qui donne le meilleur score (ou je garde la variable telle qu'elle s'il n'y a pas d'amélioration), je remplace la variable dans le jeu de données d'origine avec la variable transformée et je recommence le processus avec la variable suivante.
# Un exemple de ces tests, avec la variable `ENERGYSTARScore`, est illustré dans les cellules suivantes.

# %%
#copie train et test set
X_train_transformed = X_train.copy()
X_test_transformed = X_test.copy()

# %%
#regression de reference
linear_ref = LinearRegression()
linear_ref.fit(X_train_transformed, y_train_log)
y_linear_ref = linear_ref.predict(X_test_transformed)
score(y_test_log, y_linear_ref)
# Out:
#         Scores
# R2    0.667949
# MAE   0.227037
# RMSE  0.317900

# %%
#transformation log
X_tr = X_train_transformed.copy()
X_ts = X_test_transformed.copy()
X_tr['ENERGYSTARScore'] = np.log1p(X_tr['ENERGYSTARScore'])
X_ts['ENERGYSTARScore'] = np.log1p(X_ts['ENERGYSTARScore'])
linear_tr = LinearRegression()
linear_tr.fit(X_tr, y_train_log)
y_linear_tr = linear_tr.predict(X_ts)
score(y_test_log, y_linear_tr)
# Out:
#         Scores
# R2    0.669325
# MAE   0.225349
# RMSE  0.317241

# %%
#transformation racine carrée ou cubique
X_tr = X_train_transformed.copy()
X_ts = X_test_transformed.copy()
X_tr['ENERGYSTARScore'] = (X_tr['ENERGYSTARScore'])**0.5
X_ts['ENERGYSTARScore'] = (X_ts['ENERGYSTARScore'])**0.5
linear_tr = LinearRegression()
linear_tr.fit(X_tr, y_train_log)
y_linear_tr= linear_tr.predict(X_ts)
score(y_test_log, y_linear_tr)
# Out:
#         Scores
# R2    0.669852
# MAE   0.225878
# RMSE  0.316988

# %%
#power transformer
X_tr = X_train_transformed.copy()
X_ts = X_test_transformed.copy()
pt = PowerTransformer()
X_tr['ENERGYSTARScore'] = pt.fit_transform(X_tr[['ENERGYSTARScore']])
X_ts['ENERGYSTARScore'] = pt.transform(X_ts[['ENERGYSTARScore']])
linear_tr = LinearRegression()
linear_tr.fit(X_tr, y_train_log)
y_linear_tr = linear_tr.predict(X_ts)
score(y_test_log, y_linear_tr)
# Out:
#         Scores
# R2    0.666311
# MAE   0.227956
# RMSE  0.318683

# %%
#quantile transformer
X_tr = X_train_transformed.copy()
X_ts = X_test_transformed.copy()
qt = QuantileTransformer(output_distribution='normal')
X_tr['ENERGYSTARScore'] = qt.fit_transform(X_tr[['ENERGYSTARScore']])
X_ts['ENERGYSTARScore'] = qt.transform(X_ts[['ENERGYSTARScore']])
linear_tr = LinearRegression()
linear_tr.fit(X_tr, y_train_log)
y_linear_tr = linear_tr.predict(X_ts)
score(y_test_log, y_linear_tr)
# Out:
#         Scores
# R2    0.679929
# MAE   0.220691
# RMSE  0.312113

# %% [markdown]
# Pour la variable `ENERGYSTARScore` la meilleure transformation est la Quantile Transformation. Je modifie ainsi les train et test set et je recommence le processus.

# %%
#remplacement de la variable avec la variable transformée
X_train_transformed['ENERGYSTARScore'] = qt.fit_transform(X_train_transformed[['ENERGYSTARScore']])
X_test_transformed['ENERGYSTARScore'] = qt.transform(X_test_transformed[['ENERGYSTARScore']])

# %% [markdown]
# Dans les cellules suivantes, je presente les transformations choisies pour chaqune des variables.

# %%
X_train_transformed[['NumberofBuildings','NaturalGas_proportion','Parking_proportion']] = np.log1p(X_train_transformed[['NumberofBuildings','NaturalGas_proportion','Parking_proportion']] )
X_test_transformed[['NumberofBuildings','NaturalGas_proportion','Parking_proportion']] = np.log1p(X_test_transformed[['NumberofBuildings','NaturalGas_proportion','Parking_proportion']] )

X_train_transformed[['NumberofFloors','Building_proportion']] = np.sqrt(X_train_transformed[['NumberofFloors','Building_proportion']] )
X_test_transformed[['NumberofFloors','Building_proportion']] = np.sqrt(X_test_transformed[['NumberofFloors','Building_proportion']] )

qt = QuantileTransformer(output_distribution='normal')
X_train_transformed[['ENERGYSTARScore', 'Electricity_proportion']]=qt.fit_transform(X_train_transformed[['ENERGYSTARScore','Electricity_proportion']])
X_test_transformed[['ENERGYSTARScore','Electricity_proportion']]=qt.transform(X_test_transformed[['ENERGYSTARScore','Electricity_proportion']])

# %% [markdown]
# | Variable  |      Transformation      |
# |----------|:-------------:|
# | PrimaryPropertyType |  X    |
# | ZipCode |    X   |
# | Neighborhood | X     |
# | NumberofBuildings | log    |
# | NumberofFloors |sqrt    |
# | ENERGYSTARScore | QuantileTransformer(output_distribution='normal')      |
# | Age | X     |
# | Electricity_proportion |QuantileTransformer(output_distribution='normal')       |
# | Steam_proportion | X    |
# | NaturalGas_proportion | log     |
# | Parking_proportion | log   |
# | Building_proportion| sqrt    |
# | Side | X       |
# | LargestUSEpct | X

# %% [markdown]
# Je vais examiner la distribution des variables transformées.

# %%
#distributions variables transformées
fig, ax = plt.subplots(4, 2, figsize =(15, 15))
count = 1
for col in ['NumberofBuildings','NumberofFloors','ENERGYSTARScore', 'Electricity_proportion','NaturalGas_proportion','Parking_proportion','Building_proportion']:
    plt.subplot(4,2,count)
    plt.title(col)
    plt.hist(X_train_transformed[col],bins = 35)
    plt.xlabel(col)
    plt.ylabel('Nombre d\'immeubles')
    count +=1
fig.delaxes(ax[3][1])
plt.tight_layout()

# %% [markdown]
# Pour certaines variables l'effet n'est pas clair, mais pour `ENERGYSTARScore` et `Electricity_proportion` la distribution ressemble beaucoup plus à une distribution normale par rapport à la variable de depart (cf. `Nardi_Elena_1_notebook_exploratoire_122022`, section 4.1).
#
# Je vais entrainer des régressions linéaires sur les variables ainsi transformées.

# %%
#régression simple
linear_tr = LinearRegression()
linear_tr.fit(X_train_transformed, y_train_log)
y_linear_tr = linear_tr.predict(X_test_transformed)
score(y_test_log, y_linear_tr)
# Out:
#         Scores
# R2    0.691108
# MAE   0.213942
# RMSE  0.306614

# %%
#regression avec scaling
linear_tr_scaled = Pipeline(steps=[('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_tr_scaled.fit(X_train_transformed, y_train_log)
y_linear_tr_scaled = linear_tr_scaled.predict(X_test_transformed)
score(y_test_log, y_linear_tr_scaled)
# Out:
#         Scores
# R2    0.691108
# MAE   0.213942
# RMSE  0.306614

# %%
#régression avec features polynomiales et scaling
linear_tr_scaled_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_tr_scaled_poly.fit(X_train_transformed, y_train_log)
y_linear_tr_scaled_poly = linear_tr_scaled_poly.predict(X_test_transformed)
score(y_test_log, y_linear_tr_scaled_poly)
# Out:
#         Scores
# R2    0.679239
# MAE   0.212720
# RMSE  0.312449

# %% [markdown]
# La transformation des variables a permis une légère amélioration des scores.

# %% [markdown]
# ## 3.4 Inverses des variables

# %% [markdown]
# Je vais examiner si l'ajout des inverses des variables permet d'améliorer les scores.

# %%
#creation des jeux de données avec inverses des variables
X_train_inv, X_test_inv = inverse_variables(X_train, X_test)

# %%
#régression linéaire simple
linear_inv = LinearRegression()
linear_inv.fit(X_train_inv, y_train_log)
y_linear_inv = linear_inv.predict(X_test_inv)
score(y_test_log, y_linear_inv)
# Out:
#         Scores
# R2    0.679851
# MAE   0.219783
# RMSE  0.312151

# %%
#regréssion linéaire avec scaling
linear_inv_scaled = Pipeline(steps=[('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_inv_scaled.fit(X_train_inv, y_train_log)
y_linear_inv_scaled = linear_inv_scaled.predict(X_test_inv)
score(y_test_log, y_linear_inv_scaled)
# Out:
#         Scores
# R2    0.679851
# MAE   0.219783
# RMSE  0.312151

# %%
#regréssion linéaire avec features polynomiales et scaling
linear_inv_scaled_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('LR', LinearRegression())])
linear_inv_scaled_poly.fit(X_train_inv, y_train_log)
y_linear_inv_scaled_poly = linear_inv_scaled_poly.predict(X_test_inv)
score(y_test_log, y_linear_inv_scaled_poly)
# Out:
#            Scores
# R2   -1176.956514
# MAE      2.552747
# RMSE    18.934476

# %% [markdown]
# L'ajout des inverses des variables empire le scores, et dans le cas de features polynomiales, le modèle est même pire que le dummy model de référence (probablement en raison du surapprentissage).

# %% [markdown]
# ## 3.5  Best Linear Regression

# %% [markdown]
# La meilleure régression linéaire est celle entrainée avec le logarithme de la variable cible, les variables transformées sans inverses et sans features polynomiales.
#
# Je vais la réentraîner pour analyser le runtime, les scores sur train et test set et l'importance des variables.

# %%
#meilleur modèle
linear_best = Pipeline(steps=[('Scaler', RobustScaler()), ('LR', LinearRegression())])

# %%
#cross validation scores
cv_scores(linear_best, X_train_transformed, y_train_log)
# Out:
# [CV] END  neg_mean_absolute_error: (train=-0.225, test=-0.248) neg_root_mean_squared_error: (train=-0.325, test=-0.356) r2: (train=0.667, test=0.655) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.232, test=-0.231) neg_root_mean_squared_error: (train=-0.335, test=-0.315) r2: (train=0.662, test=0.677) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.227, test=-0.238) neg_root_mean_squared_error: (train=-0.323, test=-0.364) r2: (train=0.674, test=0.627) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.235, test=-0.211) neg_root_mean_squared_error: (train=-0.335, test=-0.314) r2: (train=0.661, test=0.679) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.229, test=-0.232) neg_root_mean_squared_error: (train=-0.333, test=-0.323) r2: (train=0.668, test=0.645) total time=   0.0s
#
# Mean runtime: 0.016
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.666349              0.656659
# MAE           0.229531              0.232089
# RMSE          0.330172              0.334349

# %% [markdown]
# En moyenne, les scores sur train folds et validation fold set sont similaires, ce qui indique qu'il n'y a pas de surapprentissage.

# %%
#score test set
y_linear_best_test = linear_best.fit(X_train_transformed, y_train_log).predict(X_test_transformed)
score(y_test_log, y_linear_best_test)
# Out:
#         Scores
# R2    0.691108
# MAE   0.213942
# RMSE  0.306614

# %% [markdown]
# Les scores sont meilleurs sur le test set par rapport aux scores obtenus avec la cross validation. Ceci pourrait être dû au fait que la taille du jeu des données est relativement petite (1656 immeubles en total - train + test) et le train test split fait en sorte que la distribution des variables du test set soit un peu différente par rapport à la distribution des variables du train set.
#
# NB: j'ai réalisé des tests avec différents train/test splits: parfois les scores sont meilleurs sur le test set que sur le train set et parfois sont pires mais globalement, pour train et test set, les scores sont similaires à ceux obtenus avec ce split.

# %%
#données prédites vs données réelles
plt.figure(figsize=(6,6))
plt.scatter(y_test_log, y_linear_best_test)
plt.title('Emissions prédites vs émission réelles')
plt.xlabel('GHGEmissionsIntensity réelle (log kg CO2/sf)')
plt.ylabel('GHGEmissionsIntensity prédite (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity prédite (log kg CO2/sf)')

# %% [markdown]
# On peut remarquer une colinéarité entre émissions prédites et réelles.

# %%
#tracé des résidus
plt.figure(figsize=(6, 6))
plt.plot(y_test_log - y_linear_best_test, 'bo')
plt.title('Tracé des résidus')
plt.xlabel('Observations')
plt.ylabel('Résidus')
# Out:
# Text(0, 0.5, 'Résidus')

# %% [markdown]
# La représentation des résidus ne présente aucune structure particulière.

# %% [markdown]
# ### Importance des variables

# %% [markdown]
# Afin de mieux comprendre le modèle, je vais examiner les coefficients de la régression.

# %%
#dataframe coefficients
feature_importance = pd.DataFrame(linear_best.steps[1][1].coef_, index= X_train.columns, columns=['Importance']).sort_values('Importance', ascending = False)

# %%
#features les plus importantes avec contribution positive à la prédiction
sns.barplot(x = feature_importance['Importance'].head(), y = feature_importance.head().index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# Les variables `Building_proportion` et `Steam_proportion` sont les variables qui contribuent le plus aux prédictions, malgré que la relation linéaire entre ces variables et la variable cible ne soit pas évidente et que pour la plupart des immeubles ces variables soient égales à 1 et 0, respectivement et donc pas trop discriminantes (cf. `Nardi_Elena_1_notebook_exploratoire_122022`, section 4.1 et 4.2.3). Probablement, ce modèle linéaire 'simple' est limité et n'arrive pas à bien capturer les relations entre variables.

# %% [markdown]
# # 4. Régression Lasso

# %% [markdown]
# Dans un premier temps, je vais entrainer des régressions Lasso sur le jeu de donné tel qu'il est, avec scaling des données et en rajoutant des features polynomiales.
#
# Ensuite je vais faire la même chose en transformant la variable cible, en testant plusieurs transformations sur les variables et en rajoutant les inverses des variables (par exemple 1/NumberofFloors).
#
# Pour le scaling, je vais utiliser le RobustScaler, qui permet de réduire l'effet des valeurs aberrantes.
#
# Je vais utiliser le jeu de données de train, X_train, pour l'entrainement et présenter les scores obtenus sur le jeu de test, X_test.

# %% [markdown]
# ## 4.1 Premières modélisations

# %%
#Lasso de base
lasso = Lasso()
lasso.fit(X_train, y_train)
y_lasso = lasso.predict(X_test)
score(y_test, y_lasso)
# Out:
#         Scores
# R2    0.183752
# MAE   1.151556
# RMSE  1.767608

# %%
#Lasso avec scaling
lasso_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Lasso', Lasso())])
lasso_scaled.fit(X_train, y_train)
y_lasso_scaled = lasso_scaled.predict(X_test)
score(y_test, y_lasso_scaled)
# Out:
#         Scores
# R2    0.008690
# MAE   1.305296
# RMSE  1.947959

# %%
#Lasso avec features polynomiales et scaling
lasso_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Lasso', Lasso())])
lasso_scaled_poly.fit(X_train, y_train)
y_lasso_scaled_poly = lasso_scaled_poly.predict(X_test)
score(y_test, y_lasso_scaled_poly )
# Out:
#         Scores
# R2    0.176480
# MAE   1.160096
# RMSE  1.775465

# %% [markdown]
# Ces scores sont pires par rapport à ceux obtenus lors des premières régressions sans régularisation (cf. section 3.1).

# %% [markdown]
# ## 4.2 Logarithme de la variable cible

# %% [markdown]
# Pour essayer d'améliorer les scores, je vais entrainer des modèles en utilisant le logarithme de la variable cible.

# %%
#Lasso simple
lasso_log = Lasso()
lasso_log.fit(X_train, y_train_log)
y_lasso_log = lasso_log.predict(X_test)
score(y_test_log, y_lasso_log)
# Out:
#         Scores
# R2    0.035302
# MAE   0.433475
# RMSE  0.541856

# %%
#Lasso avec scaling
lasso_log_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Lasso', Lasso())])
lasso_log_scaled.fit(X_train, y_train_log)
y_lasso_log_scaled  = lasso_log_scaled.predict(X_test)
score(y_test_log, y_lasso_log_scaled)
# Out:
#         Scores
# R2   -0.007004
# MAE   0.444560
# RMSE  0.553610

# %%
#Lasso avec features polynomiales et scaling
lasso_log_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Lasso', Lasso())])
lasso_log_scaled_poly.fit(X_train, y_train_log)
y_lasso_log_scaled_poly = lasso_log_scaled_poly.predict(X_test)
score(y_test_log, y_lasso_log_scaled_poly)
# Out:
#         Scores
# R2    0.022123
# MAE   0.436494
# RMSE  0.545545

# %% [markdown]
# Le passage au logarithme ne permet pas une amélioration du score R2 mais permet une nette amélioration de MAE et RMSE pas rapport au modèle Lasso de base. Je vais ainsi continuer à entrainer des régressions Lasso en utilisant le logarithme de la variable cible comme target.
#
# Je vais faire une Grid Search pour optimiser l'hyperparamètre alpha.

# %%
#hyperparamètre GridSearch
params={
     'Lasso__alpha': np.logspace(-4, 4, num = 9)
}

# %%
#GridSearchCV
GS_Lasso_log = GridSearchCV(lasso_log_scaled, params, cv=5, scoring = ('neg_mean_squared_error'), verbose=3)
GS_Lasso_log.fit(X_train, y_train_log)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5]
# [CV 5/5] END ...............Lasso__alpha=100.0;, score=-0.297 total time=   0.0s
# [CV 1/5] END ..............Lasso__alpha=1000.0;, score=-0.368 total time=   0.0s
# [CV 2/5] END ..............Lasso__alpha=1000.0;, score=-0.307 total time=   0.0s
# [CV 3/5] END ..............Lasso__alpha=1000.0;, score=-0.356 total time=   0.0s
# [CV 4/5] END ..............Lasso__alpha=1000.0;, score=-0.308 total time=   0.0s
# [CV 5/5] END ..............Lasso__alpha=1000.0;, score=-0.297 total time=   0.0s
# [CV 1/5] END .............Lasso__alpha=10000.0;, score=-0.368 total time=   0.0s
# [CV 2/5] END .............Lasso__alpha=10000.0;, score=-0.307 total time=   0.0s
# [CV 3/5] END .............Lasso__alpha=10000.0;, score=-0.356 total time=   0.0s
# [CV 4/5] END .............Lasso__alpha=10000.0;, score=-0.308 total time=   0.0s
# [CV 5/5] END .............Lasso__alpha=10000.0;, score=-0.297 total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Scaler', RobustScaler()),
#                                        ('Lasso', Lasso())]),
#              param_grid={'Lasso__alpha': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
#meilleur score
GS_Lasso_log.best_score_
# Out:
# -0.11833588021685641

# %%
#meilleur hyperparamètre 
GS_Lasso_log.best_params_
# Out:
# {'Lasso__alpha': 0.0001}

# %% [markdown]
# Je vais réentraîner les modèles avec l'hyperparamètre alpha optimisé.

# %%
#lasso simple
lasso_log = Lasso(alpha = 0.0001)
lasso_log.fit(X_train, y_train_log)
y_lasso_log = lasso_log.predict(X_test)
score(y_test_log, y_lasso_log)
# Out:
#         Scores
# R2    0.668034
# MAE   0.226907
# RMSE  0.317860

# %%
#lasso avec scaling
lasso_log_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.0001))])
lasso_log_scaled.fit(X_train, y_train_log)
y_lasso_log_scaled  = lasso_log_scaled.predict(X_test)
score(y_test_log, y_lasso_log_scaled)
# Out:
#         Scores
# R2    0.668112
# MAE   0.226866
# RMSE  0.317823

# %%
#lasso avec features polynomiales et scaling
lasso_log_poly_scaled = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.0001, max_iter=100000))])
lasso_log_poly_scaled.fit(X_train, y_train_log)
y_lasso_log_poly_scaled  = lasso_log_poly_scaled.predict(X_test)
score(y_test_log, y_lasso_log_poly_scaled)
# Out:
#         Scores
# R2    0.648766
# MAE   0.220701
# RMSE  0.326954

# %% [markdown]
# L'optimisation de l'hyperparamètre alpha a permis une amélioration substantielle des scores.

# %% [markdown]
# ## 4.3 Transformation des variables

# %% [markdown]
# Je vais utiliser les variables transformées déjà décrites dans la section 3.3. En effet, une régression Lasso reste toujours une régression linéaire et j'assume que si ces transformations ont permis d'améliorer les scores auparavant, elles devraient permettre une amélioration aussi dans ce cas.
#
# Pour l'hyperparamètre alpha, je vais garder la valeur optimisée avec GridsearchCV.

# %%
#Lasso simple
lasso_tr = Lasso(alpha = 0.001)
lasso_tr.fit(X_train_transformed, y_train_log)
y_lasso_tr = lasso_tr.predict(X_test_transformed)
score(y_test_log, y_lasso_tr)
# Out:
#         Scores
# R2    0.681709
# MAE   0.216639
# RMSE  0.311244

# %%
#lasso avec scaling
lasso_tr_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.001))])
lasso_tr_scaled.fit(X_train_transformed, y_train_log)
y_lasso_tr_scaled = lasso_tr_scaled.predict(X_test_transformed)
score(y_test_log, y_lasso_tr_scaled )
# Out:
#         Scores
# R2    0.682359
# MAE   0.216148
# RMSE  0.310926

# %%
#lasso avec features polynomiales et scaling
lasso_tr_poly_scaled = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.001, max_iter=10000))])
lasso_tr_poly_scaled.fit(X_train_transformed, y_train_log)
y_lasso_tr_poly_scaled  = lasso_tr_poly_scaled.predict(X_test_transformed)
score(y_test_log, y_lasso_tr_poly_scaled)
# Out:
#         Scores
# R2    0.696003
# MAE   0.201050
# RMSE  0.304175

# %% [markdown]
# La transformation des variables a permis une légère amélioration des scores.

# %% [markdown]
# ## 4.4 Inverses des variables

# %% [markdown]
# Je vais examiner si l'ajout des inverses des variables permet d'améliorer les scores.

# %%
#lasso simple avec inverses
lasso_inv = Lasso(alpha = 0.001, max_iter=5000)
lasso_inv.fit(X_train_inv, y_train_log)
y_lasso_inv = lasso_inv.predict(X_test_inv)
score(y_test_log, y_lasso_inv)
# Out:
#         Scores
# R2    0.669928
# MAE   0.224677
# RMSE  0.316952

# %%
#lasso avec inverses et scaling
lasso_inv_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.001))])
lasso_inv_scaled.fit(X_train_inv, y_train_log)
y_lasso_inv_scaled = lasso_inv_scaled.predict(X_test_inv)
score(y_test_log, y_lasso_inv_scaled)
# Out:
#         Scores
# R2    0.671132
# MAE   0.223032
# RMSE  0.316373

# %%
#lasso avec inverses, features polynomiales et scaling
lasso_inv_poly_scaled = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.001, max_iter = 100000))])
lasso_inv_poly_scaled.fit(X_train_inv, y_train_log)
y_lasso_inv_poly_scaled  = lasso_inv_poly_scaled.predict(X_test_inv)
score(y_test_log, y_lasso_inv_poly_scaled)
# Out:
#         Scores
# R2    0.653289
# MAE   0.219038
# RMSE  0.324842

# %% [markdown]
# Les scores empirent légèrement.

# %% [markdown]
# ## 4.5 Best Lasso Regression

# %% [markdown]
# Les meilleures régressions Lasso sont celles entrainées avec le logarithme de la variable cible et les variables transformées sans inverses.
#
# Je vais optimiser les hyperparamètres à l'aide d'une Grid Search, réentraîner un modèle utilisant les meilleurs hyperparamètres et ensuite l'analyser.

# %%
#hyperparamètres pour GridSearch
params={
    'Poly__degree' : [1, 2],
    'Poly__interaction_only' : [True, False],
    'Lasso__alpha': np.logspace(-4, 4, num = 9)
}

# %%
#GridSearchCV
lasso_best_pipeline = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Lasso', Lasso())])
GS_Lasso = GridSearchCV(lasso_best_pipeline, params, cv=5, scoring = ('neg_mean_squared_error'), verbose=3)
GS_Lasso.fit(X_train_transformed, y_train_log)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=True;, score=-0.127 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=True;, score=-0.100 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=True;, score=-0.132 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=True;, score=-0.100 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=True;, score=-0.104 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=False;, score=-0.127 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=False;, score=-0.100 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=False;, score=-0.132 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=False;, score=-0.100 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.0001, Poly__degree=1, Poly__interaction_only=False;, score=-0.104 total time=   0.0s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.185e+01, tolerance: 3.351e-02
# [CV 1/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=True;, score=-0.113 total time=   0.1s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.166e+01, tolerance: 3.513e-02
# [CV 2/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=True;, score=-0.112 total time=   0.1s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.677e+01, tolerance: 3.385e-02
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.482e+01, tolerance: 3.512e-02
# [CV 3/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=True;, score=-0.131 total time=   0.1s
# [CV 4/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=True;, score=-0.092 total time=   0.1s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.705e+01, tolerance: 3.545e-02
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.830e+01, tolerance: 3.351e-02
# [CV 5/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=True;, score=-0.106 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=False;, score=-0.107 total time=   0.1s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.449e+01, tolerance: 3.513e-02
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.632e+01, tolerance: 3.385e-02
# [CV 2/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=False;, score=-0.121 total time=   0.1s
# [CV 3/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=False;, score=-0.136 total time=   0.1s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.723e+01, tolerance: 3.512e-02
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.145e+01, tolerance: 3.545e-02
# [CV 4/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=False;, score=-0.088 total time=   0.1s
# [CV 5/5] END Lasso__alpha=0.0001, Poly__degree=2, Poly__interaction_only=False;, score=-0.111 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=True;, score=-0.129 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=True;, score=-0.099 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=True;, score=-0.133 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=True;, score=-0.100 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=True;, score=-0.105 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=False;, score=-0.129 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=False;, score=-0.099 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=False;, score=-0.133 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=False;, score=-0.100 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.001, Poly__degree=1, Poly__interaction_only=False;, score=-0.105 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=True;, score=-0.113 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=True;, score=-0.105 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=True;, score=-0.127 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=True;, score=-0.089 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=True;, score=-0.102 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=False;, score=-0.108 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=False;, score=-0.111 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=False;, score=-0.131 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=False;, score=-0.086 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.001, Poly__degree=2, Poly__interaction_only=False;, score=-0.104 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=True;, score=-0.161 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=True;, score=-0.111 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=True;, score=-0.165 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=True;, score=-0.113 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=True;, score=-0.115 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=False;, score=-0.161 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=False;, score=-0.111 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=False;, score=-0.165 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=False;, score=-0.113 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.01, Poly__degree=1, Poly__interaction_only=False;, score=-0.115 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=True;, score=-0.121 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=True;, score=-0.123 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=True;, score=-0.131 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=True;, score=-0.095 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=True;, score=-0.105 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=False;, score=-0.120 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=False;, score=-0.124 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=False;, score=-0.128 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=False;, score=-0.093 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.01, Poly__degree=2, Poly__interaction_only=False;, score=-0.107 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=True;, score=-0.190 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=True;, score=-0.176 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=True;, score=-0.193 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=True;, score=-0.151 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=True;, score=-0.141 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=False;, score=-0.190 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=False;, score=-0.176 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=False;, score=-0.193 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=False;, score=-0.151 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.1, Poly__degree=1, Poly__interaction_only=False;, score=-0.141 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=True;, score=-0.152 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=True;, score=-0.148 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=True;, score=-0.154 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=True;, score=-0.128 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=True;, score=-0.118 total time=   0.0s
# [CV 1/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=False;, score=-0.171 total time=   0.0s
# [CV 2/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=False;, score=-0.149 total time=   0.0s
# [CV 3/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=False;, score=-0.156 total time=   0.0s
# [CV 4/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=False;, score=-0.130 total time=   0.0s
# [CV 5/5] END Lasso__alpha=0.1, Poly__degree=2, Poly__interaction_only=False;, score=-0.119 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.353 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.298 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.339 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.301 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.289 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.353 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.298 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.339 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.301 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.289 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=100.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=100.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=1000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10000.0, Poly__degree=1, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=True;, score=-0.297 total time=   0.0s
# [CV 1/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.368 total time=   0.0s
# [CV 2/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.307 total time=   0.0s
# [CV 3/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.356 total time=   0.0s
# [CV 4/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.308 total time=   0.0s
# [CV 5/5] END Lasso__alpha=10000.0, Poly__degree=2, Poly__interaction_only=False;, score=-0.297 total time=   0.0s
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.758e-02, tolerance: 4.327e-02
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Poly', PolynomialFeatures()),
#                                        ('Scaler', RobustScaler()),
#                                        ('Lasso', Lasso())]),
#              param_grid={'Lasso__alpha': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04]),
#                          'Poly__degree': [1, 2],
#                          'Poly__interaction_only': [True, False]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
#meilleur score
GS_Lasso.best_score_
# Out:
# -0.10747097006945523

# %%
#meilleurs hyperparamètres
GS_Lasso.best_params_
# Out:
# {'Lasso__alpha': 0.001, 'Poly__degree': 2, 'Poly__interaction_only': True}

# %%
#meilleur modèle
lasso_best = Pipeline(steps = [('Poly', PolynomialFeatures(interaction_only=True)), ('Scaler', RobustScaler()), ('Lasso', Lasso(alpha = 0.001, max_iter=5000))])

# %%
#cross validation scores
cv_scores(lasso_best, X_train_transformed, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.207, test=-0.224) neg_root_mean_squared_error: (train=-0.304, test=-0.337) r2: (train=0.708, test=0.692) total time=   0.1s
# [CV] END  neg_mean_absolute_error: (train=-0.207, test=-0.233) neg_root_mean_squared_error: (train=-0.308, test=-0.324) r2: (train=0.713, test=0.657) total time=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.204, test=-0.225) neg_root_mean_squared_error: (train=-0.298, test=-0.357) r2: (train=0.722, test=0.641) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.214, test=-0.195) neg_root_mean_squared_error: (train=-0.313, test=-0.299) r2: (train=0.704, test=0.709) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.204, test=-0.226) neg_root_mean_squared_error: (train=-0.306, test=-0.319) r2: (train=0.720, test=0.653) total time=   0.0s
#
# Mean runtime: 0.103
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.713638              0.670360
# MAE           0.207128              0.220612
# RMSE          0.305853              0.327269

# %% [markdown]
# En moyenne, les scores sur train folds et validation fold set sont similaires, ce qui indique qu'il n'y a pas de surapprentissage.

# %%
#score test set
y_lasso_best_test = lasso_best.fit(X_train_transformed, y_train_log).predict(X_test_transformed)
score(y_test_log, y_lasso_best_test)
# Out:
#         Scores
# R2    0.692672
# MAE   0.204749
# RMSE  0.305837

# %%
#données prédites vs données réelles
plt.figure(figsize=(6,6))
plt.scatter(y_test_log, y_lasso_best_test)
plt.title('Emissions prédites vs émission réelles')
plt.xlabel('GHGEmissionsIntensity réelle (log kg CO2/sf)')
plt.ylabel('GHGEmissionsIntensity prédite (log kg CO2/sf)')
plt.xlim(0, 2.5)
plt.ylim(0, 2.5)
# Out:
# (0.0, 2.5)

# %% [markdown]
# On peut remarquer une colinéarité entre émissions prédites et réelles.

# %%
#tracé des résidus
plt.figure(figsize=(6,6))
plt.plot(y_test_log - y_lasso_best_test, 'bo')
plt.title('Tracé des résidus')
plt.xlabel('Observatiosn')
plt.ylabel('Résidus')
# Out:
# Text(0, 0.5, 'Résidus')

# %% [markdown]
# La représentation des résidus ne présente aucune structure particulière.

# %% [markdown]
# ### Importance des variables

# %% [markdown]
# Afin de mieux comprendre le modèle, je vais examiner les coefficients de la régression.

# %%
#dataframe coefficients
feature_importance_lasso = pd.DataFrame(lasso_best.steps[2][1].coef_, index=lasso_best.steps[0][1].get_feature_names_out(), columns = ['Importance']).sort_values('Importance', ascending=False)

# %%
#features les plus importantes avec contribution positive à la prédiction
sns.barplot(x = feature_importance_lasso['Importance'].head(), y = feature_importance_lasso.head().index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# Les deux variables les plus importantes sont le produit de `Steam_proportion` et `Neighborhood` et le produit de `Steam_proportion` et `NumberofFloors`. Je vais examiner leur relation avec la variable cible.

# %%
#*Neigborhood*Steam_proportion vs émissions
plt.scatter(X_train_transformed['Neighborhood']*X_train_transformed['Steam_proportion'], y_train_log)
plt.title('Neighborhood*Steam_proportion vs émissions CO2')
plt.xlabel('Neighborhood*Steam_proportion')
plt.ylabel('GHGEmissionsIntensity (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity (log kg CO2/sf)')

# %% [markdown]
# En effet, on peut voir une tendance linéaire croissante.

# %%
#NumberofFloors*Steam_proportion vs émissions
plt.scatter(X_train_transformed['NumberofFloors']*X_train_transformed['Steam_proportion'], y_train_log)
plt.title('NumberofFloors*Steam_proportion vs émissions CO2')
plt.xlabel('NumberofFloors*Steam_proportion')
plt.ylabel('GHGEmissionsIntensity (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity (log kg CO2/sf)')

# %% [markdown]
# Aussi dans ce cas, on peut voir une tendance linéaire croissante. Probablement, l'ajout des features polynomiales permet de mieux capturer la relation entre variables indépendantes et variable cible.

# %% [markdown]
# # 5.Régression Ridge

# %% [markdown]
# Dans un premier temps, je vais entrainer des régressions Ridge sur le jeu de donné tel qu'il est, avec scaling des données et en rajoutant des features polynomiales.
#
# Ensuite je vais faire la même chose en transformant la variable cible, en testant plusieurs transformations sur les variables et en rajoutant les inverses des variables (par exemple 1/NumberofFloors).
#
# Pour le scaling, je vais utiliser le RobustScaler, qui permet de réduire l'effet des valeurs aberrantes.
#
# Je vais utiliser le jeu de données de train, X_train, pour l'entrainement et présenter les scores obtenus sur le jeu de test, X_test.

# %% [markdown]
# ## 5.1 Premières modélisations

# %%
#ridge de base
ridge = Ridge()
ridge.fit(X_train, y_train)
y_ridge = ridge.predict(X_test)
score(y_test, y_ridge)
# Out:
#         Scores
# R2    0.445820
# MAE   0.871504
# RMSE  1.456466

# %%
#ridge avec scaling
ridge_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_scaled.fit(X_train, y_train)
y_ridge_scaled = ridge_scaled.predict(X_test)
score(y_test, y_ridge_scaled)
# Out:
#         Scores
# R2    0.445222
# MAE   0.872533
# RMSE  1.457251

# %%
#ridge avec features polynomiales et scaling
ridge_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_scaled_poly.fit(X_train, y_train)
y_ridge_scaled_poly = ridge_scaled_poly.predict(X_test)
score(y_test, y_ridge_scaled_poly)
# Out:
#         Scores
# R2    0.369822
# MAE   0.868310
# RMSE  1.553125

# %% [markdown]
# Les scores sont similaires aux scores obtenus avec les premières régressions linéaires (section 3.1).

# %% [markdown]
# ## 5.2 Logarithme de la variable cible

# %% [markdown]
# Pour essayer d'améliorer les scores, je vais entrainer des modèles en utilisant le logarithme de la variable cible.

# %%
#ridge simple
ridge_log = Ridge()
ridge_log.fit(X_train, y_train_log)
y_ridge_log = ridge_log.predict(X_test)
score(y_test_log, y_ridge_log)
# Out:
#         Scores
# R2    0.668381
# MAE   0.226792
# RMSE  0.317694

# %%
#ridge avec scaling
ridge_log_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_log_scaled.fit(X_train, y_train_log)
y_ridge_log_scaled = ridge_log_scaled.predict(X_test)
score(y_test_log, y_ridge_log_scaled)
# Out:
#         Scores
# R2    0.668368
# MAE   0.226811
# RMSE  0.317700

# %%
#ridge avec features polynomiales et scaling
ridge_log_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_log_scaled_poly.fit(X_train, y_train_log)
y_ridge_log_scaled_poly = ridge_log_scaled_poly.predict(X_test)
score(y_test_log, y_ridge_log_scaled_poly)
# Out:
#         Scores
# R2    0.644933
# MAE   0.221694
# RMSE  0.328733

# %% [markdown]
# Le passage au logarithme permet une nette amélioration des scores : le score R2 augmente et MAE et RMSE baissent.
# Dans la suite, je vais continuer à entrainer des régressions Ridge avec le logarithme de la variable cible comme target.

# %% [markdown]
# ## 5.3 Transformation des variables

# %% [markdown]
# Je vais utiliser les variables transformées dejà decrites dans la section 3.3.

# %%
#ridge simple
ridge_tr = Ridge()
ridge_tr.fit(X_train_transformed, y_train_log)
y_ridge_tr = ridge_tr.predict(X_test_transformed)
score(y_test_log, y_ridge_tr)
# Out:
#         Scores
# R2    0.683745
# MAE   0.216729
# RMSE  0.310247

# %%
#ridge avec scaling
ridge_tr_scaled_poly = Pipeline(steps = [('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_tr_scaled_poly.fit(X_train_transformed, y_train_log)
y_ridge_tr_scaled_poly = ridge_tr_scaled_poly.predict(X_test_transformed)
score(y_test_log, y_ridge_tr_scaled_poly)
# Out:
#         Scores
# R2    0.685388
# MAE   0.216357
# RMSE  0.309440

# %%
#ridge avec scaling
ridge_tr_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_tr_scaled_poly.fit(X_train_transformed, y_train_log)
y_ridge_tr_scaled_poly = ridge_tr_scaled_poly.predict(X_test_transformed)
score(y_test_log, y_ridge_tr_scaled_poly)
# Out:
#         Scores
# R2    0.680328
# MAE   0.209034
# RMSE  0.311918

# %% [markdown]
# La transformation des variables apport une légère amélioration aux scores.

# %% [markdown]
# ## 5.4 Inverses des variables

# %% [markdown]
# Je vais examiner si l'ajout des inverses des variables permet d'améliorer les scores.

# %%
#ridge simple avec inverses
ridge_inv = Ridge()
ridge_inv.fit(X_train_inv, y_train_log)
y_ridge_inv = ridge_inv.predict(X_test_inv)
score(y_test_log, y_ridge_inv)
# Out:
#         Scores
# R2    0.673622
# MAE   0.223133
# RMSE  0.315173

# %%
#ridge avec inverses et scaling
ridge_inv_tr_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_inv_tr_scaled.fit(X_train_inv, y_train_log)
y_ridge_inv_tr_scaled = ridge_inv_tr_scaled.predict(X_test_inv)
score(y_test_log, y_ridge_inv_tr_scaled)
# Out:
#         Scores
# R2    0.675841
# MAE   0.221844
# RMSE  0.314100

# %%
#eidge avec inverses, features polynomiales t scaling
ridge_inv_poly = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Ridge', Ridge())])
ridge_inv_poly.fit(X_train_inv, y_train_log)
y_ridge_inv_poly = ridge_inv_poly.predict(X_test_inv)
score(y_test_log, y_ridge_inv_poly)
# Out:
#         Scores
# R2    0.568627
# MAE   0.235773
# RMSE  0.362339

# %% [markdown]
# Les scores empirent légèrement dans le cas de la régression ridge sans features polynomiales et empire beaucoup plus dans le cas de la régression ridge avec features polynomiales.

# %% [markdown]
# ## 5.5 Best Ridge Regression

# %% [markdown]
# Les meilleures régressions Ridge sont celles entrainées avec le logarithme de la variable cible comme target et sur les variables transformées sans inverses.
#
# Je vais optimiser les hyperparamètres à l'aide d'une Grid Search, réentraîner un modèle utilisant les meilleurs hyperparamètres et ensuite l'analyser.

# %%
#hyperparamètres GridSearch
params={
    'Poly__degree' : [1, 2],
    'Poly__interaction_only' : [True, False],
    'Ridge__alpha': np.logspace(-4, 4, num = 9)
}

# %%
#GridSearchCV
ridge_best_pipeline = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('Ridge', Ridge())])
GS_Ridge =GridSearchCV(ridge_best_pipeline, params, cv = 5, scoring = ('neg_mean_squared_error'), verbose=3)
GS_Ridge.fit(X_train_transformed, y_train_log)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, Ridge__alpha=0.0001;, score=-0.127 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, Ridge__alpha
total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=0.1;, score=-0.132 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=0.1;, score=-0.095 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=0.1;, score=-0.106 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1.0;, score=-0.112 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1.0;, score=-0.109 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1.0;, score=-0.129 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1.0;, score=-0.090 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1.0;, score=-0.104 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10.0;, score=-0.114 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10.0;, score=-0.106 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10.0;, score=-0.126 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10.0;, score=-0.088 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10.0;, score=-0.102 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=100.0;, score=-0.120 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=100.0;, score=-0.115 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=100.0;, score=-0.125 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=100.0;, score=-0.091 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=100.0;, score=-0.102 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1000.0;, score=-0.128 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1000.0;, score=-0.122 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1000.0;, score=-0.130 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1000.0;, score=-0.103 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=1000.0;, score=-0.106 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10000.0;, score=-0.159 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10000.0;, score=-0.153 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10000.0;, score=-0.150 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10000.0;, score=-0.135 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=True, Ridge__alpha=10000.0;, score=-0.123 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.0001;, score=-0.110 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.0001;, score=-0.142 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.0001;, score=-0.164 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.0001;, score=-0.123 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.0001;, score=-0.112 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.001;, score=-0.110 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.001;, score=-0.139 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.001;, score=-0.155 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.001;, score=-0.110 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.001;, score=-0.112 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.01;, score=-0.109 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.01;, score=-0.135 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.01;, score=-0.150 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.01;, score=-0.101 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.01;, score=-0.111 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.1;, score=-0.108 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.1;, score=-0.130 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.1;, score=-0.144 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.1;, score=-0.092 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=0.1;, score=-0.111 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1.0;, score=-0.107 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1.0;, score=-0.118 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1.0;, score=-0.136 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1.0;, score=-0.087 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1.0;, score=-0.109 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10.0;, score=-0.108 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10.0;, score=-0.113 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10.0;, score=-0.131 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10.0;, score=-0.084 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10.0;, score=-0.105 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=100.0;, score=-0.117 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=100.0;, score=-0.119 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=100.0;, score=-0.128 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=100.0;, score=-0.088 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=100.0;, score=-0.104 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1000.0;, score=-0.130 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1000.0;, score=-0.123 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1000.0;, score=-0.129 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1000.0;, score=-0.101 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=1000.0;, score=-0.106 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10000.0;, score=-0.157 total time=   0.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10000.0;, score=-0.150 total time=   0.0s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10000.0;, score=-0.148 total time=   0.0s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10000.0;, score=-0.132 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, Ridge__alpha=10000.0;, score=-0.120 total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Poly', PolynomialFeatures()),
#                                        ('Scaler', RobustScaler()),
#                                        ('Ridge', Ridge())]),
#              param_grid={'Poly__degree': [1, 2],
#                          'Poly__interaction_only': [True, False],
#                          'Ridge__alpha': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
#meilleur score
GS_Ridge.best_score_
# Out:
# -0.10708571382845992

# %%
#meilleurs hyperparamètres
GS_Ridge.best_params_
# Out:
# {'Poly__degree': 2, 'Poly__interaction_only': True, 'Ridge__alpha': 10.0}

# %%
#meilleure régression Ridge
ridge_best = Pipeline(steps = [('Poly', PolynomialFeatures(interaction_only=True)), ('Scaler', RobustScaler()), ('Ridge', Ridge(alpha=10))])

# %%
#cross validation scores
cv_scores(ridge_best, X_train_transformed, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.206, test=-0.224) neg_root_mean_squared_error: (train=-0.303, test=-0.337) r2: (train=0.711, test=0.691) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.207, test=-0.233) neg_root_mean_squared_error: (train=-0.307, test=-0.325) r2: (train=0.716, test=0.655) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.204, test=-0.224) neg_root_mean_squared_error: (train=-0.297, test=-0.355) r2: (train=0.724, test=0.645) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.212, test=-0.194) neg_root_mean_squared_error: (train=-0.311, test=-0.296) r2: (train=0.708, test=0.714) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.203, test=-0.227) neg_root_mean_squared_error: (train=-0.304, test=-0.320) r2: (train=0.723, test=0.653) total time=   0.0s
#
# Mean runtime: 0.064
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.716290              0.671532
# MAE           0.206373              0.220417
# RMSE          0.304435              0.326670

# %% [markdown]
# En moyenne, les scores sur train folds et validation fold set sont similaires, ce qui indique qu'il n'y a pas de surapprentissage.

# %%
#score test set
y_ridge_best_test = ridge_best.fit(X_train_transformed, y_train_log).predict(X_test_transformed)
score(y_test_log, y_ridge_best_test)
# Out:
#         Scores
# R2    0.689757
# MAE   0.207343
# RMSE  0.307284

# %%
#données  prédites vs données reélles
plt.figure(figsize=(6,6))
plt.scatter(y_test_log, y_ridge_best_test)
plt.title('Emissions prédites vs émissions réelles')
plt.xlabel('GHGEmissionsIntensity réelle (log kg CO2/sf)')
plt.ylabel('GHGEmissionsIntensity prédite (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity prédite (log kg CO2/sf)')

# %% [markdown]
# On peut rémarquer une colinearité entre emissions predites et réeelles.

# %%
#tracé des résidus
plt.figure(figsize=(6, 6))
plt.plot(y_test_log - y_ridge_best_test, 'bo')
plt.title('Tracé des résidus')
plt.xlabel('Observations')
plt.ylabel('Résiduss')
# Out:
# Text(0, 0.5, 'Résiduss')

# %% [markdown]
# La représentation des résidus ne présente aucune structure particulière.

# %% [markdown]
# ### Importance des variables

# %% [markdown]
# Afin de mieux comprendre le modèle, je vais examiner les coefficients de la régression.

# %%
#dataframe coefficients
feature_importance_ridge = pd.DataFrame(ridge_best.steps[2][1].coef_, index = ridge_best.steps[0][1].get_feature_names_out(), columns = ['Importance']).sort_values('Importance', ascending=False)

# %%
#feature les plus importante avec contribution positive aux prédictions
sns.barplot(x = feature_importance_ridge['Importance'].head(), y = feature_importance_ridge['Importance'].head().index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# Comme dans le cas de la régression lasso, les deux variables les plus importantes sont le produit de `Steam_proportion` et `NumberofFloors` et le produit de `Steam_proportion` et `Neighborhood`.
#
# Le produit de `PrimaryPropertyType` et `Steam_proportion`  troisième variable la plus importante, a un coefficient similaire. de Je vais examiner sa relation avec la variable cible.

# %%
#NumberofFloors*Steam_proportion vs émissions
plt.scatter(X_train_transformed['PrimaryPropertyType']*X_train_transformed['Steam_proportion'], y_train_log)
plt.title('PrimaryPropertyType*Steam_proportion vs émissions CO2')
plt.xlabel('PrimaryPropertyType*Steam_proportion')
plt.ylabel('GHGEmissionsIntensity (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity (log kg CO2/sf)')

# %% [markdown]
# On peut voir une tendance linéaire croissante. Probablement, comme dans le cas de la régression lasso, l'ajout des features polynomiales permet de mieux capturer la relation entre variables indépendantes et variables cible.

# %% [markdown]
# # 6. Support Vector Regression (SVR)

# %% [markdown]
# Dans un premier temps, je vais entrainer des SVR sur le jeu de données tel qu'il est, sur le jeu avec scaling des données et en rajoutant des features polynomiales.
#
# Ensuite je vais faire la même chose en transformant la variable cible et en rajoutant les inverses des variables (par exemple 1/NumberofFloors).
#
# Pour le scaling, je vais utiliser le RobustScaler, qui permet de réduire l'effet des valeurs aberrantes.
#
# Je vais utiliser le jeu de données de train, X_train, pour l'entrainement et presenter les scores obtenus sur le jeu de test, X_test.

# %% [markdown]
# ## 6.1 Premières modélisations

# %%
#SVR de base
svr = SVR()
svr.fit(X_train, y_train)
y_svr = svr.predict(X_test)
score(y_test, y_svr)
# Out:
#         Scores
# R2   -0.025019
# MAE   1.075370
# RMSE  1.980801

# %%
#SVR avec scaling
svr_scaled = Pipeline(steps = [('Scaler',RobustScaler()), ('SVR', SVR())])
svr_scaled.fit(X_train, y_train)
y_svr_scaled = svr_scaled.predict(X_test)
score(y_test, y_svr_scaled)
# Out:
#         Scores
# R2    0.428473
# MAE   0.668462
# RMSE  1.479086

# %%
#SVR avec features polynomiales et scaling
svr_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures(interaction_only=True)), ('Scaler', RobustScaler()), ('SVR', SVR())])
svr_scaled_poly.fit(X_train, y_train)
y_svr_scaled_poly = svr_scaled_poly.predict(X_test)
score(y_test, y_svr_scaled_poly)
# Out:
#         Scores
# R2    0.373876
# MAE   0.708549
# RMSE  1.548121

# %% [markdown]
# Ces scores peuvent probablement être améliorés.

# %% [markdown]
# ## 6.2 Logarithme de la variable cible

# %% [markdown]
# Pour essayer d'améliorer les scores, je vais entrainer des modèles en utilisant le logarithme de la variable cible.

# %%
#SVR simple
svr_log = SVR()
svr_log.fit(X_train, y_train_log)
y_svr_log = svr_log.predict(X_test)
score(y_test_log, y_svr_log)
# Out:
#         Scores
# R2    0.094490
# MAE   0.398438
# RMSE  0.524971

# %%
#SVR avec scaling
svr_log_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('SVR', SVR())])
svr_log_scaled.fit(X_train, y_train_log)
y_svr_log_scaled = svr_log_scaled.predict(X_test)
score(y_test_log, y_svr_log_scaled)
# Out:
#         Scores
# R2    0.678848
# MAE   0.207147
# RMSE  0.312639

# %%
#SVR avec features polynomiales et scaling
svr_log_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures(interaction_only=True)), ('Scaler', RobustScaler()), ('SVR', SVR())])
svr_log_scaled_poly.fit(X_train, y_train_log)
y_svr_log_scaled_poly = svr_log_scaled_poly.predict(X_test)
score(y_test_log, y_svr_log_scaled_poly)
# Out:
#         Scores
# R2    0.658789
# MAE   0.214005
# RMSE  0.322255

# %% [markdown]
# Le passage au logarithme permet une amélioration substantielle des scores, qui deviennent comparables aux scores obtenus avec les meilleures régressions, sans ou avec régularisation (cf. section 3.5, 4.5 et 5.5). Ainsi, dans la suite, je vais continuer à entrainer des SVR avec le logarithme de la variable cible comme target.

# %% [markdown]
# ## 6.3 Inverses des variables

# %% [markdown]
# Je vais examiner si l'ajout des inverses des variables permet d'améliorer les scores.

# %%
#SVR simple avec inverses
svr_inv = SVR()
svr_inv.fit(X_train_inv, y_train_log)
y_svr_inv = svr_inv.predict(X_test_inv)
score(y_test_log, y_svr_inv)
# Out:
#         Scores
# R2    0.093584
# MAE   0.398493
# RMSE  0.525233

# %%
#SVR avec inverses et scaling
svr_inv_scaled = Pipeline(steps = [('Scaler', RobustScaler()), ('SVR', SVR())])
svr_inv_scaled.fit(X_train_inv, y_train_log)
y_svr_inv_scaled = svr_inv_scaled.predict(X_test_inv)
score(y_test_log,y_svr_inv_scaled)
# Out:
#         Scores
# R2    0.649300
# MAE   0.217622
# RMSE  0.326706

# %%
#SVR avec inverses, features polynomiales et scaling
svr_inv_scaled_poly = Pipeline(steps = [('Poly', PolynomialFeatures(interaction_only=True)), ('Scaler', RobustScaler()), ('SVR', SVR())])
svr_inv_scaled_poly.fit(X_train_inv, y_train_log)
y_svr_inv_scaled_poly = svr_inv_scaled_poly.predict(X_test_inv)
score(y_test_log,y_svr_inv_scaled_poly)
# Out:
#         Scores
# R2    0.661987
# MAE   0.213826
# RMSE  0.320742

# %% [markdown]
# Les scores empirent légèrement.

# %% [markdown]
# ## 6.4 Best SVR

# %% [markdown]
# Les meilleures SVR sont celles entrainées avec le logarithme de la variable cible comme target sans inverses.
#
# Je vais optimiser les hyperparamètres à l'aide d'une Grid Search, réentraîner un modèle utilisant les meilleurs hyperparamètres et ensuite l'analyser.

# %%
#hyperparamètres GridSearch
params = {
    'Poly__degree' : [1, 2],
    'Poly__interaction_only' : [True, False],
    'SVR__C': np.logspace(-3, 3, 7),
    'SVR__epsilon' : np.logspace(-6, 1, 8)
}

# %%
#GridSearchCV
svr_best_pipeline = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('SVR', SVR())])
GS_SVR = GridSearchCV(svr_best_pipeline, params, cv=5, scoring = 'neg_mean_squared_error', verbose = 3)
GS_SVR.fit(X_train, y_train_log)
# Out:
# Fitting 5 folds for each of 224 candidates, totalling 1120 fits
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-06;, score=-0.368 total time=   0.2s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-06;, score=-0.315 total time=   0.1s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-06;, score=-0.362 total time=   0.1s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-06;, score=-0.299 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-06;, score=-0.283 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-05;, score=-0.368 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-05;, score=-0.315 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-05;, score=-0.362 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-05;, score=-0.299 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=1e-05;, score=-0.283 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.0001;, score=-0.368 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.0001;, score=-0.315 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.0001;, score=-0.362 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.0001;, score=-0.299 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.0001;, score=-0.283 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.001;, score=-0.368 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.001;, score=-0.315 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.001;, score=-0.362 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.001;, score=-0.299 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.001;, score=-0.284 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.01;, score=-0.369 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.01;, score=-0.314 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.01;, score=-0.361 total time=   0.1s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.01;, score=-0.300 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.01;, score=-0.284 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.1;, score=-0.365 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.1;, score=-0.312 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.1;, score=-0.359 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.1;, score=-0.299 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon=0.1;, score=-0.282 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, SVR__C=0.001, SVR__epsilon

#              scoring='neg_mean_squared_error', verbose=3)

# %%
#meilleur score
GS_SVR.best_score_
# Out:
# -0.11425211553133632

# %%
#meilleurs hyperparamètres
GS_SVR.best_params_
# Out:
# {'Poly__degree': 2,
#  'Poly__interaction_only': False,
#  'SVR__C': 100.0,
#  'SVR__epsilon': 0.1}

# %%
#meilleure SVR
svr_best_pipeline = Pipeline(steps = [('Poly', PolynomialFeatures()), ('Scaler', RobustScaler()), ('SVR', SVR(C = 100, epsilon = 0.1))])

# %%
#cross validation scores
cv_scores(svr_best_pipeline, X_train, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END  neg_mean_absolute_error: (train=-0.212, test=-0.232) neg_root_mean_squared_error: (train=-0.322, test=-0.347) r2: (train=0.672, test=0.674) total time=   0.1s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.212, test=-0.224) neg_root_mean_squared_error: (train=-0.324, test=-0.322) r2: (train=0.684, test=0.662) total time=   0.1s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.170, test=-0.254) neg_root_mean_squared_error: (train=-0.257, test=-0.385) r2: (train=0.794, test=0.583) total time=   0.3s
# [CV] END  neg_mean_absolute_error: (train=-0.218, test=-0.203) neg_root_mean_squared_error: (train=-0.329, test=-0.312) r2: (train=0.673, test=0.683) total time=   0.1s
# [CV] END  neg_mean_absolute_error: (train=-0.210, test=-0.226) neg_root_mean_squared_error: (train=-0.324, test=-0.320) r2: (train=0.687, test=0.652) total time=   0.1s
#
# Mean runtime: 0.186
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.8s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.702100              0.650806
# MAE           0.204382              0.227574
# RMSE          0.311018              0.336974

# %% [markdown]
# En moyenne, les scores sur train folds et validation fold set sont similaires, ce qui indique qu'il n'y a pas de surapprentissage.

# %%
#scores test set
y_SVR_best_test = svr_best_pipeline.fit(X_train, y_train_log).predict(X_test)
score(y_test_log, y_SVR_best_test)
# Out:
#         Scores
# R2    0.666899
# MAE   0.209127
# RMSE  0.318403

# %%
#données prédites vs données réelles
plt.figure(figsize=(6,6))
plt.scatter(y_test_log, y_SVR_best_test)
plt.title('Emissions prédites vs émissions réelles')
plt.xlabel('GHGEmissionsIntensity réelle (log kg CO2/sf)')
plt.ylabel('GHGEmissionsIntensity prédite (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity prédite (log kg CO2/sf)')

# %% [markdown]
# On peut remarquer une colinéarité entre émissions prédites et réelles.

# %%
#tracé des résidus
plt.figure(figsize=(6,6))
plt.plot(y_test_log - y_SVR_best_test, 'bo')
plt.title('Tracé des résidus')
plt.xlabel('Observation')
plt.ylabel('Résidus')
# Out:
# Text(0, 0.5, 'Résidus')

# %% [markdown]
# La représentation des résidus ne présente aucune structure particulière.

# %% [markdown]
# ### Importance des variables

# %% [markdown]
# Pour étudier l'importance des variables je vais étudier l'importance de la caractéristique de permutation, qui est définie comme la diminution du score d'un modèle lorsqu'une seule valeur de caractéristique est mélangée au hasard.

# %%
#permutation importance
perm_importance = permutation_importance(svr_best_pipeline.steps[2][1], svr_best_pipeline.steps[1][1].transform(svr_best_pipeline.steps[0][1].transform(X_test)), y_test_log)

# %%
#dataframe permutation importance
perm_imp_pd = pd.DataFrame(perm_importance.importances_mean, index = svr_best_pipeline.steps[0][1].get_feature_names_out(), columns = ['Permutation Importance']).sort_values('Permutation Importance', ascending = False)

# %%
#plot variables plus importantes
sns.barplot(perm_imp_pd['Permutation Importance'].head(), perm_imp_pd.head().index)
# Out:
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Permutation Importance'>

# %% [markdown]
# La variable la plus importante est le produit de `PrimaryPropertyType` et `NaturalGas_proportion`.

# %% [markdown]
# # 7. RandomForest

# %% [markdown]
# Dans un premier temps, je vais entrainer des Random Forest Regressors sur le jeu de données tel qu'il est et en rajoutant des features polynomiales.
#
# Ensuite je vais faire la même chose en transformant la variable cible et en rajoutant les inverses des variables (par exemple 1/NumberofFloors).
#
# Je vais utiliser le jeu de données de train, X_train, pour l'entrainement et presenter les scores obtenus sur le jeu de test, X_test.

# %% [markdown]
# ## 7.1 Premières modélisations

# %%
#random forest de base
RFR = RandomForestRegressor()
RFR.fit(X_train, y_train)
y_RFR = RFR.predict(X_test)
score(y_test, y_RFR)
# Out:
#         Scores
# R2    0.476856
# MAE   0.686801
# RMSE  1.415095

# %%
#random forest avec feature polynomiales
RFR_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('RFR',RandomForestRegressor())])
RFR_poly.fit(X_train, y_train)
y_RFR_poly = RFR_poly.predict(X_test)
score(y_test, y_RFR_poly)
# Out:
#         Scores
# R2    0.348579
# MAE   0.729517
# RMSE  1.579085

# %% [markdown]
# Ces scores peuvent probablement être améliorés.

# %% [markdown]
# ## 7.2 Logarithme de la variable cible

# %% [markdown]
# Pour essayer d'améliorer les scores, je vais entrainer des modèles en utilisant le logarithme de la variable cible.

# %%
#random forest simple
RFR_log = RandomForestRegressor()
RFR_log.fit(X_train, y_train_log)
y_RFR_log = RFR_log.predict(X_test)
score(y_test_log, y_RFR_log)
# Out:
#         Scores
# R2    0.696553
# MAE   0.199733
# RMSE  0.303899

# %%
#random forest avec feature polynomiales
RFR_log_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('RFR',RandomForestRegressor())])
RFR_log_poly.fit(X_train, y_train_log)
y_RFR_log_poly = RFR_log_poly.predict(X_test)
score(y_test_log, y_RFR_log_poly)
# Out:
#         Scores
# R2    0.705448
# MAE   0.195981
# RMSE  0.299412

# %% [markdown]
# Le passage au logarithme permet une amélioration substantielle des scores, qui surpassent les scores obtenus avec les meilleures régressions (sans ou avec régularisation) et le meilleur SVR (cf. section 3.5, 4.5, 5.5 et 6.4). Ainsi, dans la suite, je vais continuer à entrainer des régressions Random Forest avec le logarithme de la variable cible comme target.

# %% [markdown]
# ## 7.3 Inverses des variables

# %% [markdown]
# Je vais examiner si l'ajout des inverses des variables permet d'améliorer les scores.

# %%
#random forest simple
RFR_inv = RandomForestRegressor()
RFR_inv.fit(X_train_inv, y_train_log)
y_RFR_inv = RFR_inv.predict(X_test_inv)
score(y_test_log, y_RFR_inv)
# Out:
#         Scores
# R2    0.700198
# MAE   0.198467
# RMSE  0.302069

# %%
#random forest avec features polynomiales
RFR_inv_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('RFR', RandomForestRegressor())])
RFR_inv_poly.fit(X_train_inv, y_train_log)
y_RFR_inv_poly = RFR_inv_poly.predict(X_test_inv)
score(y_test_log, y_RFR_inv_poly)
# Out:
#         Scores
# R2    0.713154
# MAE   0.195187
# RMSE  0.295470

# %% [markdown]
# L'ajout des inverses des variables permet une légère amélioration des scores; cependant, étant donné que l'amélioration n'est pas élevée et que ajouter des variables implique une augmentation du temps de calcul, je préfère poursuivre les modélisations sans inverses des variable.

# %% [markdown]
# ## 7.4 Best Random Forest Regression

# %% [markdown]
# Je vais optimiser les hyperparamètres à l'aide d'une Grid Search, réentraîner un modèle utilisant les meilleurs hyperparamètres et ensuite l'analyser.

# %%
#hyperparamètres pour Grid Search
params = {
    'Poly__degree' : [1,2],
    'Poly__interaction_only': [True, False],
    'RFR__n_estimators' : [1, 2, 5, 10, 50, 100, 200, 500],
    'RFR__max_features' : [1, 2, 5, 10, 20, 50]
}

# %%
#GridSearchCV
RFR_best_pipeline = Pipeline(steps=[('Poly', PolynomialFeatures()), ('RFR', RandomForestRegressor())])
GS_RFR = GridSearchCV(RFR_best_pipeline, params, cv= 5, scoring = 'neg_mean_squared_error', verbose = 3)
GS_RFR.fit(X_train, y_train_log)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=1;, score=-0.284 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=1;, score=-0.245 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=1;, score=-0.264 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=1;, score=-0.261 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=1;, score=-0.229 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=2;, score=-0.230 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=2;, score=-0.238 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=2;, score=-0.209 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=2;, score=-0.226 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=2;, score=-0.253 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=5;, score=-0.160 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=5;, score=-0.148 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=5;, score=-0.189 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=5;, score=-0.145 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=5;, score=-0.141 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=10;, score=-0.136 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=10;, score=-0.153 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=10;, score=-0.172 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=10;, score=-0.126 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=10;, score=-0.127 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=50;, score=-0.127 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=50;, score=-0.118 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=50;, score=-0.159 total time=   0.1s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=50;, score=-0.111 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=50;, score=-0.115 total time=   0.1s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=100;, score=-0.134 total time=   0.2s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=100;, score=-0.114 total time=   0.2s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=100;, score=-0.145 total time=   0.2s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=100;, score=-0.116 total time=   0.2s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=100;, score=-0.115 total time=   0.1s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=200;, score=-0.130 total time=   0.4s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=200;, score=-0.115 total time=   0.4s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=200;, score=-0.148 total time=   0.4s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=200;, score=-0.111 total time=   0.4s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=200;, score=-0.111 total time=   0.4s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=500;, score=-0.129 total time=   1.1s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=500;, score=-0.113 total time=   1.1s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=500;, score=-0.150 total time=   1.1s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=500;, score=-0.109 total time=   1.1s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=1, RFR__n_estimators=500;, score=-0.114 total time=   1.1s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=1;, score=-0.292 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=1;, score=-0.352 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=1;, score=-0.247 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=1;, score=-0.263 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=1;, score=-0.258 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=2;, score=-0.223 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=2;, score=-0.180 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=2;, score=-0.241 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=2;, score=-0.191 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=2;, score=-0.190 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=5;, score=-0.131 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=5;, score=-0.131 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=5;, score=-0.167 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=5;, score=-0.125 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=5;, score=-0.138 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=10;, score=-0.121 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=10;, score=-0.116 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=10;, score=-0.168 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=10;, score=-0.116 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=10;, score=-0.121 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=50;, score=-0.120 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=50;, score=-0.102 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=50;, score=-0.140 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=50;, score=-0.100 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=50;, score=-0.106 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=100;, score=-0.115 total time=   0.2s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=100;, score=-0.101 total time=   0.2s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators=100;, score=-0.142 total time=   0.2s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, RFR__max_features=2, RFR__n_estimators
#  -0.12143983 -0.11423084 -0.10416056 -0.10409222 -0.1021023  -0.10180734
#  -0.3453046  -0.20364156 -0.1488436  -0.1335825  -0.11950744 -0.11704233
#  -0.11881528 -0.11654057 -0.26421943 -0.17661412 -0.1360558  -0.1182249
#  -0.11108462 -0.11046084 -0.11007719 -0.10817689 -0.24762556 -0.16685194
#  -0.12975097 -0.11439685 -0.10369617 -0.10251014 -0.10230191 -0.10149809
#  -0.22706108 -0.15432078 -0.1224459  -0.11109649 -0.10335159 -0.10225359
#  -0.10115059 -0.10039917 -0.20765883 -0.15491853 -0.11863045 -0.10970802
#  -0.10184248 -0.10101581 -0.10102442 -0.1002708  -0.20349694 -0.15585122
#  -0.12469036 -0.11285855 -0.10116699 -0.10273026 -0.10119578 -0.10122892]
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Poly', PolynomialFeatures()),
#                                        ('RFR', RandomForestRegressor())]),
#              param_grid={'Poly__degree': [1, 2],
#                          'Poly__interaction_only': [True, False],
#                          'RFR__max_features': [1, 2, 5, 10, 20, 50],
#                          'RFR__n_estimators': [1, 2, 5, 10, 50, 100, 200, 500]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
#meilleur score
GS_RFR.best_score_
# Out:
# -0.099826190367547

# %%
#meilleurs hyperparamètres
GS_RFR.best_params_
# Out:
# {'Poly__degree': 1,
#  'Poly__interaction_only': True,
#  'RFR__max_features': 10,
#  'RFR__n_estimators': 200}

# %%
#meilleur RFR
RFR_best = RandomForestRegressor(max_features=10, n_estimators = 200)

# %%
#cross validation scores
cv_scores(RFR_best, X_train, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END  neg_mean_absolute_error: (train=-0.079, test=-0.214) neg_root_mean_squared_error: (train=-0.120, test=-0.320) r2: (train=0.955, test=0.723) total time=   1.6s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.080, test=-0.209) neg_root_mean_squared_error: (train=-0.122, test=-0.293) r2: (train=0.955, test=0.720) total time=   1.6s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.4s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.078, test=-0.224) neg_root_mean_squared_error: (train=-0.116, test=-0.355) r2: (train=0.958, test=0.645) total time=   1.5s
# [CV] END  neg_mean_absolute_error: (train=-0.082, test=-0.188) neg_root_mean_squared_error: (train=-0.124, test=-0.293) r2: (train=0.954, test=0.721) total time=   1.5s
# [CV] END  neg_mean_absolute_error: (train=-0.078, test=-0.225) neg_root_mean_squared_error: (train=-0.120, test=-0.320) r2: (train=0.957, test=0.653) total time=   1.6s
#
# Mean runtime: 1.593
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.5s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.955571              0.692271
# MAE           0.079497              0.211989
# RMSE          0.120468              0.315941

# %% [markdown]
# Les scores sur le validation fold sont en moyenne nettement pires par rapport aux scores sur les train folds, ce qui indique que probablement le modèle est en train de over-fitter ; néanmoins, il s'agit des meilleurs scores obtenus jusqu'à la.

# %%
#scores test set
y_RFR_best_test = RFR_best.fit(X_train, y_train_log).predict(X_test)
score(y_test_log, y_RFR_best_test)
# Out:
#         Scores
# R2    0.709274
# MAE   0.193707
# RMSE  0.297461

# %%
#données prédites vs données reélles
plt.figure(figsize=(6, 6))
plt.scatter(y_test_log, y_RFR_best_test)
plt.title('Emissions prédites vs émissions réelles')
plt.xlabel('GHGEmissionsIntensity réelle (log kg CO2/sf)')
plt.ylabel('GHGEmissionsIntensity prédite (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity prédite (log kg CO2/sf)')

# %% [markdown]
# On peut remarquer une colinéarité entre émissions prédites et réelles.

# %%
#tracé des résidus
plt.figure(figsize=(6, 6))
plt.plot(y_test_log - y_RFR_best_test, 'bo')
plt.title('Tracé des résidus')
plt.xlabel('Observations')
plt.ylabel('Résidus')
# Out:
# Text(0, 0.5, 'Résidus')

# %% [markdown]
# La représentation des résidus ne présente aucune structure particulière.

# %% [markdown]
# ### Importance des variables

# %%
#dataframe importance
feature_importance_RFR = pd.DataFrame(RFR_best.feature_importances_, index = X_train.columns, columns = ['Importance']).sort_values('Importance', ascending=False)

# %%
#plot des features les plus importantes
sns.barplot(x = feature_importance_RFR['Importance'].head(10), y = feature_importance_RFR['Importance'].head(10).index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# La variable la plus importante est le pourcentage de consommation du à l'electricité.

# %% [markdown]
# # 8. XGBoost

# %% [markdown]
# Dans un premier temps, je vais entrainer des XGBoost Regressors sur le jeu de données tel qu'il est et en rajoutant des features polynomiales.
#
# Ensuite je vais faire la même chose en transformant la variable cible et en rajoutant les inverses des variables (par exemple 1/NumberofFloors).
#
# Je vais utiliser le jeu de données de train, X_train, pour l'entrainement et presenter les scores obtenus sur le jeu de test, X_test.

# %% [markdown]
# ## 8.1 Premières modélisations

# %%
#XGBoost de base
XGB = XGBRegressor()
XGB.fit(X_train, y_train)
y_XGB = XGB.predict(X_test)
score(y_test, y_XGB)
# Out:
#         Scores
# R2    0.474851
# MAE   0.698093
# RMSE  1.417804

# %%
#XGBoost avec features polynomiales
XGB_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('XGB', XGBRegressor())])
XGB_poly.fit(X_train, y_train)
y_XGB_poly = XGB_poly.predict(X_test)
score(y_test, y_XGB_poly)
# Out:
#         Scores
# R2    0.221537
# MAE   0.805344
# RMSE  1.726211

# %% [markdown]
# Ces scores peuvent probablement être améliorés.

# %% [markdown]
# ## 8.2 Logarithme de la variable cible

# %% [markdown]
# Pour essayer d'améliorer les scores, je vais entrainer des modèles en utilisant le logarithme de la variable cible.

# %%
XGB_log = XGBRegressor()
XGB_log.fit(X_train, y_train_log)
y_XGB_log = XGB_log.predict(X_test)
score(y_test_log, y_XGB_log)
# Out:
#         Scores
# R2    0.648432
# MAE   0.204899
# RMSE  0.327110

# %%
#XGB avec features polynomiales
XGB_poly_log = Pipeline(steps=[('Poly', PolynomialFeatures()),('XGB', XGBRegressor())])
XGB_poly_log.fit(X_train, y_train_log)
y_XGB_poly_log = XGB_poly_log.predict(X_test)
score(y_test_log, y_XGB_poly_log)
# Out:
#         Scores
# R2    0.661267
# MAE   0.211120
# RMSE  0.321083

# %% [markdown]
# Le passage au logarithme permet une nette amélioration des scores : le score R2 augmente et MAE et RMSE baissent.
# Dans la suite, je vais continuer à entrainer des régressions XGBoost avec le logarithme de la variable cible comme target.

# %% [markdown]
# ## 8.3 Inverses des variables

# %% [markdown]
# Je vais examiner si l'ajout des inverses des variables permet d'améliorer les scores.

# %%
#XGB simple
XGB_inv = XGBRegressor()
XGB_inv.fit(X_train_inv, y_train_log)
y_XGB_inv = XGB_inv.predict(X_test_inv)
score(y_test_log, y_XGB_inv)
# Out:
#         Scores
# R2    0.648432
# MAE   0.204899
# RMSE  0.327110

# %%
#XGB avec features polynomiales
XGB_inv_poly = Pipeline(steps=[('Poly', PolynomialFeatures()), ('XGB', XGBRegressor())])
XGB_inv_poly.fit(X_train_inv, y_train_log)
y_XGB_inv_poly = XGB_inv_poly.predict(X_test_inv)
score(y_test_log, y_XGB_inv_poly)
# Out:
#         Scores
# R2    0.671748
# MAE   0.210066
# RMSE  0.316076

# %% [markdown]
# L'ajout de variables inverses permet une légère amélioration des scores dans le cas de la régression avec features polynomiale. Cependant, étant donné que l'amélioration n'est pas élevée et qu’ajouter les inverses des variables avec leurs features polynomiales implique une augmentation du temps de calcul, je préfère poursuivre les modélisations sans inverses des variables.

# %% [markdown]
# ## 8.4 Best XGB Regression

# %% [markdown]
# Je vais optimiser les hyperparamètres à l'aide d'une Grid Search, réentraîner un modèle utilisant les meilleurs hyperparamètres et ensuite l'analyser.

# %%
#hyperparamètres pour Grid Search
params = {
    'Poly__degree' : [1,2],
    'Poly__interaction_only': [True, False],
    'XGB__n_estimators' : [1, 2, 5, 10, 20, 50, 100, 200, 500],
    'XGB__max_depth' : [2, 5, 10, 20, 50]
}

# %%
XGB_best_pipeline = Pipeline(steps=[('Poly', PolynomialFeatures()), ('XGB', XGBRegressor())])
GS_XGB = GridSearchCV(XGB_best_pipeline, params, cv = 5, scoring = ('neg_mean_squared_error'), verbose = 3)
GS_XGB.fit(X_train, y_train_log)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=1;, score=-0.320 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=1;, score=-0.262 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=1;, score=-0.313 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=1;, score=-0.256 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=1;, score=-0.238 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=2;, score=-0.241 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=2;, score=-0.194 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=2;, score=-0.251 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=2;, score=-0.191 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=2;, score=-0.193 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=5;, score=-0.158 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=5;, score=-0.121 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=5;, score=-0.180 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=5;, score=-0.123 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=5;, score=-0.138 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=10;, score=-0.127 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=10;, score=-0.100 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=10;, score=-0.152 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=10;, score=-0.100 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=10;, score=-0.121 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=20;, score=-0.114 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=20;, score=-0.095 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=20;, score=-0.137 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=20;, score=-0.093 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=20;, score=-0.112 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=50;, score=-0.104 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=50;, score=-0.100 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=50;, score=-0.129 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=50;, score=-0.088 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=50;, score=-0.109 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=100;, score=-0.103 total time=   0.0s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=100;, score=-0.104 total time=   0.0s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=100;, score=-0.127 total time=   0.0s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=100;, score=-0.086 total time=   0.0s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=100;, score=-0.111 total time=   0.0s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=200;, score=-0.107 total time=   0.1s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=200;, score=-0.104 total time=   0.1s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=200;, score=-0.131 total time=   0.1s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=200;, score=-0.089 total time=   0.1s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=200;, score=-0.111 total time=   0.1s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=500;, score=-0.115 total time=   0.3s
# [CV 2/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=500;, score=-0.108 total time=   0.3s
# [CV 3/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=500;, score=-0.140 total time=   0.3s
# [CV 4/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=500;, score=-0.098 total time=   0.3s
# [CV 5/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=2, XGB__n_estimators=500;, score=-0.116 total time=   0.3s
# [CV 1/5] END Poly__degree=1, Poly__interaction_only=True, XGB__max_depth=5, XGB__n_estimators
total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=5;, score=-0.133 total time=   0.1s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=5;, score=-0.128 total time=   0.1s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=5;, score=-0.163 total time=   0.1s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=5;, score=-0.104 total time=   0.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=5;, score=-0.130 total time=   0.0s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=10;, score=-0.118 total time=   0.2s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=10;, score=-0.120 total time=   0.2s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=10;, score=-0.139 total time=   0.2s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=10;, score=-0.097 total time=   0.2s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=10;, score=-0.118 total time=   0.2s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=20;, score=-0.117 total time=   0.5s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=20;, score=-0.123 total time=   0.5s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=20;, score=-0.136 total time=   0.4s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=20;, score=-0.097 total time=   0.5s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=20;, score=-0.119 total time=   0.5s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=50;, score=-0.117 total time=   1.0s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=50;, score=-0.124 total time=   1.1s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=50;, score=-0.135 total time=   0.9s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=50;, score=-0.096 total time=   1.0s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=50;, score=-0.119 total time=   1.1s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=100;, score=-0.117 total time=   1.1s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=100;, score=-0.124 total time=   1.1s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=100;, score=-0.135 total time=   0.9s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=100;, score=-0.096 total time=   1.1s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=100;, score=-0.119 total time=   1.1s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=200;, score=-0.117 total time=   1.4s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=200;, score=-0.124 total time=   1.3s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=200;, score=-0.135 total time=   1.3s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=200;, score=-0.096 total time=   1.3s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=200;, score=-0.119 total time=   1.4s
# [CV 1/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=500;, score=-0.117 total time=   2.1s
# [CV 2/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=500;, score=-0.124 total time=   1.9s
# [CV 3/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=500;, score=-0.135 total time=   1.9s
# [CV 4/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=500;, score=-0.096 total time=   1.7s
# [CV 5/5] END Poly__degree=2, Poly__interaction_only=False, XGB__max_depth=50, XGB__n_estimators=500;, score=-0.119 total time=   1.7s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Poly', PolynomialFeatures()),
#                                        ('XGB',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      callbacks=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      colsample_bytree=None,
#                                                      early_stopping_rounds=None,
#                                                      enable_categorical=False,
#                                                      eval_metric=None,
#                                                      feature_types=None,
#                                                      gamma=None, gpu_id=None,
#                                                      grow_policy=None,
#                                                      importance_type=N...
#                                                      max_leaves=None,
#                                                      min_child_weight=None,
#                                                      missing=nan,
#                                                      monotone_constraints=None,
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=None, ...))]),
#              param_grid={'Poly__degree': [1, 2],
#                          'Poly__interaction_only': [True, False],
#                          'XGB__max_depth': [2, 5, 10, 20, 50],
#                          'XGB__n_estimators': [1, 2, 5, 10, 20, 50, 100, 200,
#                                                500]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
#meilleur score
GS_XGB.best_score_
# Out:
# -0.10399448022412043

# %%
#meilleurs hyperparamètres
GS_XGB.best_params_
# Out:
# {'Poly__degree': 1,
#  'Poly__interaction_only': True,
#  'XGB__max_depth': 5,
#  'XGB__n_estimators': 50}

# %%
#meilleur XGBoost
XGB_best = XGBRegressor(max_depth=5, n_estimators=50)

# %%
#cross validation scores
cv_scores(XGB_best, X_train, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.075, test=-0.221) neg_root_mean_squared_error: (train=-0.110, test=-0.332) r2: (train=0.962, test=0.701) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.071, test=-0.213) neg_root_mean_squared_error: (train=-0.103, test=-0.309) r2: (train=0.968, test=0.688) total time=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.077, test=-0.225) neg_root_mean_squared_error: (train=-0.114, test=-0.354) r2: (train=0.960, test=0.646) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.074, test=-0.186) neg_root_mean_squared_error: (train=-0.108, test=-0.291) r2: (train=0.965, test=0.724) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.071, test=-0.223) neg_root_mean_squared_error: (train=-0.105, test=-0.323) r2: (train=0.967, test=0.647) total time=   0.0s
#
# Mean runtime: 0.099
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.964297              0.681137
# MAE           0.073750              0.213457
# RMSE          0.107848              0.321776

# %% [markdown]
# De même que pour le Random Forest, les scores sur le validation fold sont en moyenne nettement pires par rapport aux scores sur les train folds, ce qui indique que probablement le modèle est en train de over-fitter ; néanmoins, il s'agit des bons scores, comparables à ceux obtenus avec le Random Forest.

# %%
#scores test set
y_XGB_best_test = XGB_best.fit(X_train, y_train_log).predict(X_test)
score(y_test_log, y_XGB_best_test)
# Out:
#         Scores
# R2    0.692890
# MAE   0.194965
# RMSE  0.305728

# %%
#données prédites vs données réelles
plt.figure(figsize=(6, 6))
plt.scatter(y_test_log, y_XGB_best_test)
plt.title('Emissions prédites vs émissions réelles')
plt.xlabel('GHGEmissionsIntensity réelle (log kg CO2/sf)')
plt.ylabel('GHGEmissionsIntensity prédite (log kg CO2/sf)')
# Out:
# Text(0, 0.5, 'GHGEmissionsIntensity prédite (log kg CO2/sf)')

# %% [markdown]
# On peut remarquer une colinéarité entre émissions prédites et réelles.

# %%
#tracé des résidus
plt.figure(figsize=(6, 6))
plt.plot(y_test_log - y_XGB_best_test, 'bo')
plt.title('Tracé des résidus')
plt.xlabel('Observations')
plt.ylabel('Résidus')
# Out:
# Text(0, 0.5, 'Résidus')

# %% [markdown]
# La représentation des résidus ne présente aucune structure particulière.

# %% [markdown]
# ### Importance des variables

# %%
#dataframe importance
feature_importance_XGB = pd.DataFrame(XGB_best.feature_importances_, index = X_train.columns, columns = ['Importance']).sort_values('Importance', ascending=False)

# %%
#plot des l'importance des variables
sns.barplot(x = feature_importance_XGB['Importance'].head(10), y = feature_importance_XGB['Importance'].head(10).index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# # 9. Comparaison des modèles et sélection du meilleur modèle

# %% [markdown]
# Pour tous les modèles, les meilleurs résultats ont et obtenus avec le logarithme de la variable cible comme target.
# Pour les modèles linéaires, les transformation suivantes ont été utilisées:
#
# | Variable  |      Transformation      |
# |----------|:-------------:|
# | PrimaryPropertyType |  X    |
# | ZipCode |    X   |
# | Neighborhood | X     |
# | NumberofBuildings | log    |
# | NumberofFloors |sqrt    |
# | ENERGYSTARScore | QuantileTransformer(output_distribution='normal')      |
# | Age | X     |
# | Electricity_proportion |QuantileTransformer(output_distribution='normal')       |
# | Steam_proportion | X    |
# | NaturalGas_proportion | log     |
# | Parking_proportion | log   |
# | Building_proportion| sqrt    |
# | Side | X       |
# | LargestUSEpct | X

# %% [markdown]
# | Modèle   |    Polynomial(degree=2)     |Inverses |Hyperparamètres|     R2     |  MAE |  RMSE | Runtime moyen (s)|
# |----------|:-------------:|:-------------:|:-------------:|:-------------:|:------:|------:|------:|
# | Baseline |  X     | X | |-0.004635 |1.414362|2.386248|0.002
# | Linear Regression |  X     | X | |0.656659 |0.232089|0.334349|0.016
# |Lasso |  ✔ (interaction_only = True)  | X   |alpha = 0.001|0.670360|0.220612|0.327269|0.103
# |Ridge |  ✔(interaction_only = True)   |X   | alpha = 10   |0.671532 |0.220417|0.326670|0.064
# |SVR |   ✔  | X  |C=100, epsilon=0.1| 0.650806 |0.227574|0.336974|0.186
# |Random Forest |   X  | X  |max_features = 10 estimators = 200|0.692271|0.211989|0.315941|1.593
# |XGBoost |  X  | X  |max_depth = 5, n_estimators = 50|0.681137|0.213457|0.321776|0.099

# %% [markdown]
# Les meilleurs scores (les scores obtenus avec la cross-validation) ont été obtenus avec les modèles d'arbres. Les scores pour Random Forest sont  légèrement  meilleurs par rapport aux scores obtenus avec XGBoost. Cependant, je vais retenir le XGBoost comme meilleur modèle, car son runtime est très petit par rapport au runtime de Random Forest.

# %% [markdown]
# # 10. Analyse de l'intérêt de l'Energy Star Score et explication du modèle

# %% [markdown]
# ## 10.1 Analyse de l'Energy Star Score

# %% [markdown]
# Dans un premier temps, je vais reentrainer le meilleur modèle, le XGBoost Regressor, sur le jeu des données complet (c'est à dire avec `ENERGYSTARScore` imputé) mais sans la variable `ENERGYSTARScore`. Ensuite, je vais entrainer le modèle sur un jeu des données composé des immeubles pour lesquels cette variable était manquante et un jeu des données pour lequel cette variable n'était pas manquante. La comparaison des scores des différents modèles me permettra de conclure sur la pertinence de l’`ENERGYSTARScore` pour la prédiction d’émissions.

# %% [markdown]
# Pour rappel, voici les scores du meilleur XGBoost sur le test set complet:

# %%
#cross validation scores
cv_scores(XGB_best, X_train, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.075, test=-0.221) neg_root_mean_squared_error: (train=-0.110, test=-0.332) r2: (train=0.962, test=0.701) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.071, test=-0.213) neg_root_mean_squared_error: (train=-0.103, test=-0.309) r2: (train=0.968, test=0.688) total time=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.077, test=-0.225) neg_root_mean_squared_error: (train=-0.114, test=-0.354) r2: (train=0.960, test=0.646) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.074, test=-0.186) neg_root_mean_squared_error: (train=-0.108, test=-0.291) r2: (train=0.965, test=0.724) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.071, test=-0.223) neg_root_mean_squared_error: (train=-0.105, test=-0.323) r2: (train=0.967, test=0.647) total time=   0.0s
#
# Mean runtime: 0.106
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.964297              0.681137
# MAE           0.073750              0.213457
# RMSE          0.107848              0.321776

# %%
#scores test set
score(y_test_log, y_XGB_best_test)
# Out:
#         Scores
# R2    0.692890
# MAE   0.194965
# RMSE  0.305728

# %% [markdown]
# ### 10.1.1 Entrainement sur le jeu de données complet sans ENERGY STAR Score

# %%
#suppression variable ENERGYSTARScore
X_train_reduced = X_train.drop('ENERGYSTARScore', axis = 1)
X_test_reduced = X_test.drop('ENERGYSTARScore', axis = 1)

# %%
#entrainement sans ENERGYSTARScore
XGB_best_reduced = XGBRegressor(max_depth=5, n_estimators=50)
XGB_best_reduced.fit(X_train_reduced, y_train_log)
y_XGB_best_reduced = XGB_best_reduced.predict(X_test_reduced)

# %%
#cross validation scores
cv_scores(XGB_best, X_train_reduced, y_train_log)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.093, test=-0.241) neg_root_mean_squared_error: (train=-0.132, test=-0.343) r2: (train=0.945, test=0.680) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.095, test=-0.243) neg_root_mean_squared_error: (train=-0.131, test=-0.330) r2: (train=0.948, test=0.646) total time=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.091, test=-0.271) neg_root_mean_squared_error: (train=-0.127, test=-0.392) r2: (train=0.949, test=0.566) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.098, test=-0.217) neg_root_mean_squared_error: (train=-0.136, test=-0.315) r2: (train=0.944, test=0.677) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.091, test=-0.251) neg_root_mean_squared_error: (train=-0.125, test=-0.340) r2: (train=0.954, test=0.607) total time=   0.0s
#
# Mean runtime: 0.106
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.948059              0.634868
# MAE           0.093595              0.244336
# RMSE          0.130182              0.344147

# %%
#score test set
y_XGB_best_reduced = XGB_best.fit(X_train_reduced, y_train_log).predict(X_test_reduced)
score(y_test_log, y_XGB_best_reduced)
# Out:
#         Scores
# R2    0.654463
# MAE   0.219151
# RMSE  0.324292

# %% [markdown]
# Les scores sur empirent legerement.

# %% [markdown]
# ### 10.1.2 Entrainement sur le jeu de données partiel avec ENERGY STAR Score

# %%
#lecture données
train_with_ESS = pd.read_csv('Data/GHE_train_with_ESS.csv')
test_with_ESS = pd.read_csv('Data/GHE_test_with_ESS.csv')

# %%
#separation variable cible et independantes
y_train_with_ESS = train_with_ESS['GHGEmissionsIntensity']
X_train_with_ESS = train_with_ESS.drop(['GHGEmissionsIntensity'], axis = 1)
y_test_with_ESS = test_with_ESS['GHGEmissionsIntensity']
X_test_with_ESS = test_with_ESS.drop(['GHGEmissionsIntensity'], axis = 1)

# %%
#encodage des données
te = TargetEncoder(cols = categorical_columns)
X_train_with_ESS = te.fit_transform(X_train_with_ESS, y_train_with_ESS)
X_test_with_ESS = te.transform(X_test_with_ESS)
# Out:
# Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
# Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327

# %%
#transformation logarithme de la variable cible
y_train_log_with_ESS = np.log1p(y_train_with_ESS)
y_test_log_with_ESS = np.log1p(y_test_with_ESS)

# %%
#meilleur modèle
XGB_best_with_EES = XGBRegressor(max_depth=5, n_estimators=50)

# %%
#cross validation scores
cv_scores(XGB_best_with_EES, X_train_with_ESS, y_train_log_with_ESS)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.030, test=-0.129) neg_root_mean_squared_error: (train=-0.042, test=-0.207) r2: (train=0.993, test=0.842) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.033, test=-0.189) neg_root_mean_squared_error: (train=-0.047, test=-0.321) r2: (train=0.991, test=0.660) total time=   0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.028, test=-0.151) neg_root_mean_squared_error: (train=-0.040, test=-0.231) r2: (train=0.994, test=0.792) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.029, test=-0.140) neg_root_mean_squared_error: (train=-0.041, test=-0.251) r2: (train=0.994, test=0.738) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.031, test=-0.149) neg_root_mean_squared_error: (train=-0.043, test=-0.225) r2: (train=0.993, test=0.796) total time=   0.0s
#
# Mean runtime: 0.087
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.993101              0.765291
# MAE           0.030059              0.151413
# RMSE          0.042653              0.246918

# %%
#score test set
y_with_EES = XGB_best_with_EES.fit(X_train_with_ESS, y_train_log_with_ESS).predict(X_test_with_ESS)
score(y_test_log_with_ESS, y_with_EES)
# Out:
#         Scores
# R2    0.786364
# MAE   0.158877
# RMSE  0.238127

# %% [markdown]
# Sur le jeu de données composé des immeubles pour lesquels `ENERGYSTARScore` n'était pas manquantes, les scores sont même meilleurs que sur le jeu de données complet avec imputation de la variables.

# %% [markdown]
# ### 10.1.3 Entrainement sur le jeu de données partiel sans ENERGY STAR Score

# %%
#lecture données
train_without_ESS = pd.read_csv('Data/GHE_train_without_ESS.csv')
test_without_ESS = pd.read_csv('Data/GHE_test_without_ESS.csv')

# %%
#separation variable cible et independantes + supression variable manquante
y_train_without_ESS = train_without_ESS['GHGEmissionsIntensity']
X_train_without_ESS = train_without_ESS.drop(['GHGEmissionsIntensity', 'ENERGYSTARScore'], axis = 1)
y_test_without_ESS = test_without_ESS['GHGEmissionsIntensity']
X_test_without_ESS = test_without_ESS.drop(['GHGEmissionsIntensity', 'ENERGYSTARScore'], axis = 1)

# %%
#encodage des données
te = TargetEncoder(cols = categorical_columns)
X_train_without_ESS = te.fit_transform(X_train_without_ESS, y_train_without_ESS)
X_test_without_ESS = te.transform(X_test_without_ESS)
# Out:
# Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
# Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327

# %%
#transformation logarithme de la variable cible
y_train_log_without_ESS = np.log1p(y_train_without_ESS)
y_test_log_without_ESS = np.log1p(y_test_without_ESS)

# %%
#meilleur modèle
XGB_best_without_EES = XGBRegressor(max_depth = 5, n_estimators =50)

# %%
#cross validation scores
cv_scores(XGB_best_without_EES, X_train_without_ESS, y_train_log_without_ESS)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.037, test=-0.337) neg_root_mean_squared_error: (train=-0.055, test=-0.454) r2: (train=0.993, test=0.440) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.043, test=-0.335) neg_root_mean_squared_error: (train=-0.060, test=-0.459) r2: (train=0.991, test=0.444) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.046, test=-0.373) neg_root_mean_squared_error: (train=-0.066, test=-0.498) r2: (train=0.988, test=0.540) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.045, test=-0.327) neg_root_mean_squared_error: (train=-0.063, test=-0.448) r2: (train=0.991, test=0.441) total time=   0.0s
# [CV] END  neg_mean_absolute_error: (train=-0.045, test=-0.319) neg_root_mean_squared_error: (train=-0.064, test=-0.408) r2: (train=0.990, test=0.546) total time=   0.0s
#
# Mean runtime: 0.062
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
#       Mean Train Folds  Mean Validation Fold
# R2            0.990568              0.482103
# MAE           0.042945              0.338126
# RMSE          0.061552              0.453579

# %%
#score test set
y_without_EES = XGB_best_without_EES.fit(X_train_without_ESS, y_train_log_without_ESS).predict(X_test_without_ESS)
score(y_test_log_without_ESS, y_without_EES)
# Out:
#         Scores
# R2    0.454005
# MAE   0.350302
# RMSE  0.482659

# %% [markdown]
# Les scores sur le validation fold et sur le test set sont nettement pires. Ainsi, même si fastidieux à calculer, l'**ENERGY STAR Score permet d'obtenir des meilleures prédictions et on ne peut pas s'en passer.**

# %% [markdown]
# ## 10.2 Explication du modèle

# %% [markdown]
# Pour le meilleur modèle (entrainé sur le jeu de données complet imputé), je vais examiner l'importance des variables en utilisant les valeurs de Shap.

# %%
#calcul shap values
shap.initjs()
explainer = shap.TreeExplainer(XGB_best)
shap_values = explainer.shap_values(X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
#summary plot bar
shap.summary_plot(shap_values, X_test, plot_type="bar", max_display=10)

# %%
#summary plot
shap.summary_plot(shap_values, X_test, max_display= 10)

# %% [markdown]
# Comme dejà vu dans la section 8.4, les variables qui impactent le plus les prédictions sont `Electricity_proportion` et `PrimaryPropertType`. La variable `PrimaryPropertType` avait ete encodée avec le TargetEncoder, il est logique que plus sa valeur est grande, plus la valeur de la prédiction soit elevée.
#
#
# A l'aide des facteurs d'émissions de CO<sub>2</sub>, qui indiquent la quantité de CO<sub>2</sub> émise lors de la combustion d'un combustible donné et pour une unité d'énergie, je vais voir si l'impact de la variable `Electricity_proportion` sur la prédiction est logique.

# %% [markdown]
# D'après le site https://data.seattle.gov/dataset/2016-Building-Energy-Benchmarking/2bpz-gwpy, les facteurs d'émissions sont les suivants:
#  - Electricity factor: 52.44 lbs CO2e/MWh = 23.59 kg CO2e/MWh = 6.94 kg CO2e/MMBtu
#  - Steam factor: 170.17 lbs CO2e/MMBtu = 77.11 kg CO2e/MMBtu
#  - Gas factor : 53.11 kg CO2e/MMBtu
#
# Le facteur d'émission le plus petit est celui de l’électricité : en effet, la plupart de l'électricité de la ville de Seattle vient des centrales hydroélectriques (https://en.wikipedia.org/wiki/Seattle_City_Light), ce qui implique des faibles émissions de gaz à effet de serre. Ainsi, dans un immeuble, plus la proportion de consommation due à l'électricité est grande (par rapport à la proportion de gaz et steam), plus faibles seront les émissions.

# %% [markdown]
# # 11. Conclusions

# %% [markdown]
# Pour résumer, j’ai :
#  - encodé les données avec le TargetEncoder
# - testé plusieurs types de régressions (linéaires avec ou sans régularisation, SVR et modèles d'arbres)
# - examiné l'effet des transformations des variables
#  - examiné l'effet de la transformation log de la variables cible
#  -examiné l'effet de l'ajout des inverses des variables
#  - examiné l'effet de l'ajout des variables polynomiales
#  - pour chaque type de régression, j'ai utilisé la GridSearchCV pour optimiser les hyperparamètres et analysé le meilleur modèle.
#
# Le meilleur modèle pour la prédiction d’émissions CO<sub>2</sub> est le XGBoost, et la variable qui impacte le plus les prédictions et le pourcentage de consommation électrique par rapport à la consommation totale. Ceci suggère que, pour limiter les émissions, il faudrait privilégier l'électricité comme source d'énergie.
#
# L'ENERGY STAR Score, même si ce n'est pas la variable qui impacte le plus le modèle, permet d'obtenir des meilleurs résultats. Ainsi, il faut continuer à le calculer. Cependant, le calcul de l’ENERGY STAR Score se base sur plusieurs caractéristiques du bâtiment, telles que taille, le nombre d'occupants/travailleurs, le nombre d'équipements pour le chauffage ou réfrigération, etc. En ayant ces données et en les utilisant pour la modélisation, peut-être on pourrait obtenir des meilleurs scores sans utiliser directement l'ENERGY STAR Score.
